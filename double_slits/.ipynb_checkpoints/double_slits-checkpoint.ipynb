# %%
import h5py
import matplotlib.pyplot as plt
import meep as mp
import numpy as np
import os
import shutil

# %%
from matplotlib.colors import LinearSegmentedColormap

# Increase the default resolution for images
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Plot everything on a dark background
plt.style.use('dark_background')

# Some custom colormaps
cmap_alpha = LinearSegmentedColormap.from_list(
    'custom_alpha', [[1, 1, 1, 0], [1, 1, 1, 1]])
cmap_blue = LinearSegmentedColormap.from_list(
    'custom_blue', [[0, 0, 0], [0, 0.66, 1], [1, 1, 1]])

def label_plot(ax, title=None, xlabel=None, ylabel=None, elapsed=None):
    """
    Add a title and x/y labels to the plot.
    """
    if title:
        ax.set_title(title)
    elif elapsed is not None:
        ax.set_title(f'{elapsed:0.1f} fs')
    if xlabel is not False:
        ax.set_xlabel('x (μm)'if xlabel is None else xlabel)
    if ylabel is not False:
        ax.set_ylabel('y (μm)'if ylabel is None else ylabel)

def plot_eps_data(eps_data, domain, ax=None, **kwargs):
    """
    Plot the wall geometry (dielectric data) within the domain.
    """
    ax = ax or plt.gca()
    print(f'ax = {ax}')
    ax.imshow(eps_data.T, cmap=cmap_alpha, extent=domain, origin='lower')
    label_plot(ax, **kwargs)

def plot_ez_data(ez_data, domain, ax=None, vmax=None, aspect=None, **kwargs):
    """
    Plot the amplitude of the complex-valued electric field
    data within the domain.
    """
    ax = ax or plt.gca()
    ax.imshow(
        np.abs(ez_data.T),
        interpolation='spline36',
        cmap=cmap_blue,
        extent=domain,
        vmax=vmax,
        aspect=aspect,
        origin='lower',
        )
    label_plot(ax, **kwargs)

def plot_pml(pml_thickness, domain, ax=None):
    ax = ax or plt.gca()
    x_start = domain[0] + pml_thickness
    x_end = domain[1] - pml_thickness
    y_start = domain[2] + pml_thickness
    y_end = domain[3] - pml_thickness
    rect = plt.Rectangle(
        (x_start, y_start),
        x_end - x_start,
        y_end - y_start,
        fill=None,
        color='#fff',
        linestyle='dashed',
        )
    ax.add_patch(rect)

# %%
# The speed of light in μm/fs
SOL = 299792458e-9

# 2D spatial domain measured in μm
domain = [0, 30, -10, 10]
center = mp.Vector3(
    (domain[1] + domain[0]) / 2,
    (domain[3] + domain[2]) / 2,
    )
cell_size = mp.Vector3(
    domain[1] - domain[0],
    domain[3] - domain[2],
    )

# %%
# Dimensions of wall with two apertures
wall_position = 10
wall_thickness = 0.5
aperture_width = 1
inner_wall_len = 4  # wall separating the apertures
outer_wall_len = (
    cell_size[1]
    - 2*aperture_width
    - inner_wall_len
    ) / 2

# Define a wall material with high dielectric constant,
# effectively blocking light and reflecting it instead
material = mp.Medium(epsilon=1e6)

# Define the wall as an array of 3 blocks arranged vertically
geometry = [
    mp.Block(
        mp.Vector3(wall_thickness, outer_wall_len, mp.inf),
        center=mp.Vector3(
            wall_position - center.x,
            domain[3] - outer_wall_len / 2),
        material=material),
    mp.Block(
        mp.Vector3(wall_thickness, outer_wall_len, mp.inf),
        center=mp.Vector3(
            wall_position - center.x,
            domain[2] + outer_wall_len / 2),
        material=material),
    mp.Block(
        mp.Vector3(wall_thickness, inner_wall_len, mp.inf),
        center=mp.Vector3(wall_position - center.x, 0),
        material=material),
    ]

# Perfectly matched layer of thickness 1
pml_thickness = 1
pml_layers = [mp.PML(pml_thickness)]

# %%
# Extract and visualize the dielectric data (wall geometry)
sim = mp.Simulation(cell_size=cell_size, geometry=geometry, resolution=10)
sim.init_sim()
eps_data = sim.get_array(center=mp.Vector3(), size=cell_size, component=mp.Dielectric)
ax = plt.gca()
plot_pml(pml_thickness, domain, ax=ax)
plot_eps_data(eps_data, domain, ax=ax)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000283957 s
# Working in 2D dimensions.
# Computational cell is 30 x 20 x 0 with resolution 10
#      block, center = (-5,6.5,0)
#           size (0.5,7,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
#      block, center = (-5,-6.5,0)
#           size (0.5,7,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
#      block, center = (-5,0,0)
#           size (0.5,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
# time for set_epsilon = 0.0635078 s
# -----------
# ax = Axes(0.125,0.11;0.775x0.77)

# %%
# Light wavelength, frequency, and beam width
source_lambda = 0.47  # in μm
source_frequency = 1 / source_lambda
source_beam_width = 6

# %%
# A method to return a complex-valued plane wave in the x-direction
def plane_wave(x):
    return np.exp(2j * np.pi / source_lambda * x)

# Plot the plane wave
xarr = np.linspace(0, 10*source_lambda, 1000)
wave = plane_wave(xarr)
plt.plot(xarr, wave.real)
plt.xlabel('x (μm)')
plt.ylabel('Amplitude')
plt.grid(True)

# %%
# A method to compute the Gaussian profile in the y-direction
def gaussian_profile(y):
    return np.exp(-y**2 / (2 * (source_beam_width / 2)**2))

# Plot the Guassian profile
yarr = np.linspace(domain[2], domain[3], 200)
prof = gaussian_profile(yarr)
plt.plot(yarr, prof)
plt.xlabel('y (μm)')
plt.ylabel('Amplitude')
plt.grid(True)

# %%
# A 2D grid of points
X, Y = np.meshgrid(xarr, yarr)

# Plot the combined terms
combined = plane_wave(X) * gaussian_profile(Y)
plt.imshow(
    np.real(combined),
    cmap='coolwarm',
    aspect='auto',
    extent=[xarr[0], xarr[-1], yarr[0], yarr[-1]],
    origin='lower',
    )
plt.xlabel('x (μm)')
plt.ylabel('y (μm)')
# Out:
# Text(0, 0.5, 'y (μm)')

# %%
def amp_func(pos):
    return plane_wave(pos[0]) * gaussian_profile(pos[1])

source = mp.Source(
    src=mp.ContinuousSource(
        frequency=source_frequency,
        is_integrated=True,
        ),
    component=mp.Ez,
    center= mp.Vector3(1, 0, 0) - center,  # positioned far-left, excluding PML
    size=mp.Vector3(y=cell_size[1]),       # span entire height, including PML
    amp_func=amp_func,
    )

# %%
# Define resolution in terms of smallest component
smallest_length = min(
    source_lambda,
    wall_thickness,
    aperture_width,
    inner_wall_len,
    )
pixel_count = 10
resolution = int(np.ceil(pixel_count / smallest_length))
print('Simulation resolution:', resolution)
# Out:
# Simulation resolution: 22

# %%
# Simulation object
sim = mp.Simulation(
    cell_size=cell_size,
    sources=[source],
    boundary_layers=pml_layers,
    geometry=geometry,
    resolution=resolution,
    force_complex_fields=True,
    )

# Convenience method to extract Ez and dielectric data
def get_data(sim, cell_size):
    ez_data = sim.get_array(
        center=mp.Vector3(), size=cell_size, component=mp.Ez)
    eps_data = sim.get_array(
        center=mp.Vector3(), size=cell_size, component=mp.Dielectric)
    return ez_data, eps_data
    
# Run simulation until light travels full length (plus some)
sim.run(until=cell_size[0] + 10)
ez_data, eps_data = get_data(sim, cell_size)

# Plot simulation
ax = plt.gca()
plot_ez_data(ez_data, domain, ax=ax)
plot_eps_data(eps_data, domain, ax=ax)
plot_pml(pml_thickness, domain, ax=ax)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000234842 s
# Working in 2D dimensions.
# Computational cell is 30 x 20 x 0 with resolution 22
#      block, center = (-5,6.5,0)
#           size (0.5,7,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
#      block, center = (-5,-6.5,0)
#           size (0.5,7,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
#      block, center = (-5,0,0)
#           size (0.5,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
# time for set_epsilon = 0.279011 s
# -----------
# Meep: using complex fields.
# Meep progress: 29.0/40.0 = 72.5% done in 4.0s, 1.5s to go
# on time step 1276 (time=29), 0.00313579 s/step
# run 0 finished at t = 40.0 (1760 timesteps)
# ax = Axes(0.125,0.11;0.775x0.77)

# %%
# Sim duration and number of snapshots
sim_time = 120  # in fs
n_frames = 120
digit_of_frames = len(str(n_frames))

# Where to save the results
sim_path = 'simulation.h5'

# Simulation object
sim = mp.Simulation(
    cell_size=cell_size,
    sources=[source],
    boundary_layers=pml_layers,
    geometry=geometry,
    resolution=resolution,
    force_complex_fields=True,
    )

def simulate(sim, sim_path, sim_time, n_frames):
    
    # Remove previous sim file, if any
    if os.path.exists(sim_path):
        os.remove(sim_path)

    # Time delta (in fs) between snapshots. Note that
    # we subtract 1 because we include the initial state
    # as the first frame.
    fs_delta = sim_time / (n_frames - 1)
    
    # Save data to an HDF5 binary file
    with h5py.File(sim_path, 'a') as f:
    
        # Save simulation params for future reference
        f.attrs['sim_time'] = sim_time
        f.attrs['n_frames'] = n_frames
        f.attrs['fs_delta'] = fs_delta
        f.attrs['resolution'] = sim.resolution
        
        # Save initial state as first frame
        sim.init_sim()
        ez_data, eps_data = get_data(sim, cell_size)
        f.create_dataset(
            'ez_data',
            shape=(n_frames, *ez_data.shape),
            dtype=ez_data.dtype,
            )
        f.create_dataset(
            'eps_data',
            shape=eps_data.shape,
            dtype=eps_data.dtype,
            )
        f['ez_data'][0]  = ez_data
        f['eps_data'][:] = eps_data
    
        # Simulate and capture remaining snapshots
        for i in range(1, n_frames):
    
            # Run until the next frame time
            sim.run(until=SOL * fs_delta)
    
            # Capture electral field data    
            ez_data, _ = get_data(sim, cell_size)
            f['ez_data'][i]  = ez_data

simulate(sim, sim_path, sim_time, n_frames)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000230074 s
# Working in 2D dimensions.
# Computational cell is 30 x 20 x 0 with resolution 22
#      block, center = (-5,6.5,0)
#           size (0.5,7,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
#      block, center = (-5,-6.5,0)
#           size (0.5,7,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
#      block, center = (-5,0,0)
#           size (0.5,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1e+06,1e+06,1e+06)
# time for set_epsilon = 0.293949 s
# -----------
# Meep: using complex fields.
# run 0 finished at t = 0.3181818181818182 (14 timesteps)
# run 1 finished at t = 0.6363636363636364 (28 timesteps)
# run 2 finished at t = 0.9545454545454546 (42 timesteps)
# run 3 finished at t = 1.2727272727272727 (56 timesteps)
# run 4 finished at t = 1.590909090909091 (70 timesteps)
# run 5 finished at t = 1.9090909090909092 (84 timesteps)
# run 6 finished at t = 2.2272727272727275 (98 timesteps)
# run 7 finished at t = 2.5454545454545454 (112 timesteps)
# run 8 finished at t = 2.8636363636363638 (126 timesteps)
# run 9 finished at t = 3.181818181818182 (140 timesteps)
# run 10 finished at t = 3.5 (154 timesteps)
# run 11 finished at t = 3.8181818181818183 (168 timesteps)
# run 12 finished at t = 4.136363636363637 (182 timesteps)
# run 13 finished at t = 4.454545454545455 (196 timesteps)
# run 14 finished at t = 4.7727272727272725 (210 timesteps)
# run 15 finished at t = 5.090909090909091 (224 timesteps)
# run 16 finished at t = 5.409090909090909 (238 timesteps)
# run 17 finished at t = 5.7272727272727275 (252 timesteps)
# run 18 finished at t = 6.045454545454546 (266 timesteps)
# run 19 finished at t = 6.363636363636364 (280 timesteps)
# run 20 finished at t = 6.681818181818182 (294 timesteps)
# run 21 finished at t = 7.0 (308 timesteps)
# run 22 finished at t = 7.318181818181818 (322 timesteps)
# run 23 finished at t = 7.636363636363637 (336 timesteps)
# run 24 finished at t = 7.954545454545455 (350 timesteps)
# run 25 finished at t = 8.272727272727273 (364 timesteps)
# run 26 finished at t = 8.590909090909092 (378 timesteps)
# run 27 finished at t = 8.90909090909091 (392 timesteps)
# run 28 finished at t = 9.227272727272728 (406 timesteps)
# run 29 finished at t = 9.545454545454545 (420 timesteps)
# run 30 finished at t = 9.863636363636363 (434 timesteps)
# on time step 434 (time=9.86364), 0.00926649 s/step
# run 31 finished at t = 10.181818181818182 (448 timesteps)
# run 32 finished at t = 10.5 (462 timesteps)
# run 33 finished at t = 10.818181818181818 (476 timesteps)
# run 34 finished at t = 11.136363636363637 (490 timesteps)
# run 35 finished at t = 11.454545454545455 (504 timesteps)
# run 36 finished at t = 11.772727272727273 (518 timesteps)
# run 37 finished at t = 12.090909090909092 (532 timesteps)
# run 38 finished at t = 12.40909090909091 (546 timesteps)
# run 39 finished at t = 12.727272727272728 (560 timesteps)
# run 40 finished at t = 13.045454545454545 (574 timesteps)
# run 41 finished at t = 13.363636363636363 (588 timesteps)
# run 42 finished at t = 13.681818181818182 (602 timesteps)
# run 43 finished at t = 14.0 (616 timesteps)
# run 44 finished at t = 14.318181818181818 (630 timesteps)
# run 45 finished at t = 14.636363636363637 (644 timesteps)
# run 46 finished at t = 14.954545454545455 (658 timesteps)
# run 47 finished at t = 15.272727272727273 (672 timesteps)
# run 48 finished at t = 15.590909090909092 (686 timesteps)
# run 49 finished at t = 15.90909090909091 (700 timesteps)
# run 50 finished at t = 16.227272727272727 (714 timesteps)
# run 51 finished at t = 16.545454545454547 (728 timesteps)
# run 52 finished at t = 16.863636363636363 (742 timesteps)
# run 53 finished at t = 17.181818181818183 (756 timesteps)
# run 54 finished at t = 17.5 (770 timesteps)
# run 55 finished at t = 17.81818181818182 (784 timesteps)
# run 56 finished at t = 18.136363636363637 (798 timesteps)
# run 57 finished at t = 18.454545454545457 (812 timesteps)
# run 58 finished at t = 18.772727272727273 (826 timesteps)
# run 59 finished at t = 19.09090909090909 (840 timesteps)
# run 60 finished at t = 19.40909090909091 (854 timesteps)
# run 61 finished at t = 19.727272727272727 (868 timesteps)
# run 62 finished at t = 20.045454545454547 (882 timesteps)
# on time step 893 (time=20.2955), 0.00871726 s/step
# run 63 finished at t = 20.363636363636363 (896 timesteps)
# run 64 finished at t = 20.681818181818183 (910 timesteps)
# run 65 finished at t = 21.0 (924 timesteps)
# run 66 finished at t = 21.31818181818182 (938 timesteps)
# run 67 finished at t = 21.636363636363637 (952 timesteps)
# run 68 finished at t = 21.954545454545457 (966 timesteps)
# run 69 finished at t = 22.272727272727273 (980 timesteps)
# run 70 finished at t = 22.59090909090909 (994 timesteps)
# run 71 finished at t = 22.90909090909091 (1008 timesteps)
# run 72 finished at t = 23.227272727272727 (1022 timesteps)
# run 73 finished at t = 23.545454545454547 (1036 timesteps)
# run 74 finished at t = 23.863636363636363 (1050 timesteps)
# run 75 finished at t = 24.181818181818183 (1064 timesteps)
# run 76 finished at t = 24.5 (1078 timesteps)
# run 77 finished at t = 24.81818181818182 (1092 timesteps)
# run 78 finished at t = 25.136363636363637 (1106 timesteps)
# run 79 finished at t = 25.454545454545457 (1120 timesteps)
# run 80 finished at t = 25.772727272727273 (1134 timesteps)
# run 81 finished at t = 26.09090909090909 (1148 timesteps)
# run 82 finished at t = 26.40909090909091 (1162 timesteps)
# run 83 finished at t = 26.727272727272727 (1176 timesteps)
# run 84 finished at t = 27.045454545454547 (1190 timesteps)
# run 85 finished at t = 27.363636363636363 (1204 timesteps)
# run 86 finished at t = 27.681818181818183 (1218 timesteps)
# run 87 finished at t = 28.0 (1232 timesteps)
# run 88 finished at t = 28.31818181818182 (1246 timesteps)
# run 89 finished at t = 28.636363636363637 (1260 timesteps)
# run 90 finished at t = 28.954545454545457 (1274 timesteps)
# run 91 finished at t = 29.272727272727273 (1288 timesteps)
# run 92 finished at t = 29.590909090909093 (1302 timesteps)
# run 93 finished at t = 29.90909090909091 (1316 timesteps)
# run 94 finished at t = 30.227272727272727 (1330 timesteps)
# run 95 finished at t = 30.545454545454547 (1344 timesteps)
# on time step 1354 (time=30.7727), 0.00867945 s/step
# run 96 finished at t = 30.863636363636363 (1358 timesteps)
# run 97 finished at t = 31.181818181818183 (1372 timesteps)
# run 98 finished at t = 31.5 (1386 timesteps)
# run 99 finished at t = 31.81818181818182 (1400 timesteps)
# run 100 finished at t = 32.13636363636364 (1414 timesteps)
# run 101 finished at t = 32.45454545454545 (1428 timesteps)
# run 102 finished at t = 32.77272727272727 (1442 timesteps)
# run 103 finished at t = 33.09090909090909 (1456 timesteps)
# run 104 finished at t = 33.40909090909091 (1470 timesteps)
# run 105 finished at t = 33.72727272727273 (1484 timesteps)
# run 106 finished at t = 34.04545454545455 (1498 timesteps)
# run 107 finished at t = 34.36363636363637 (1512 timesteps)
# run 108 finished at t = 34.68181818181818 (1526 timesteps)
# run 109 finished at t = 35.0 (1540 timesteps)
# run 110 finished at t = 35.31818181818182 (1554 timesteps)
# run 111 finished at t = 35.63636363636364 (1568 timesteps)
# run 112 finished at t = 35.95454545454545 (1582 timesteps)
# run 113 finished at t = 36.27272727272727 (1596 timesteps)
# run 114 finished at t = 36.59090909090909 (1610 timesteps)
# run 115 finished at t = 36.909090909090914 (1624 timesteps)
# run 116 finished at t = 37.22727272727273 (1638 timesteps)
# run 117 finished at t = 37.54545454545455 (1652 timesteps)
# run 118 finished at t = 37.86363636363637 (1666 timesteps)

# %%
# Make a folder to store figures, and remove the folder if it has existed
folder_name = 'figures'
if os.path.exists(folder_name):
    shutil.rmtree(folder_name)
os.mkdir(folder_name)

with h5py.File(sim_path, 'r') as f:
    os.chdir(folder_name)
    for k in range(n_frames):
        ax = plt.gca()
        ez_data = f['ez_data'][k]
        eps_data = f['eps_data'][:]
        elapsed = k * f.attrs['fs_delta']
        vmax = 0.6  # force consistent brightness
        plot_ez_data(ez_data, domain, ax=ax, vmax=vmax, elapsed=elapsed)
        plot_eps_data(eps_data, domain, ax=ax)
        plot_pml(pml_thickness, domain, ax=ax)
        filename = f'{k}'.zfill(digit_of_frames) + '.png'
        plt.savefig(filename)
        plt.close()  # close the figure to avoid running out for memory and inefficiency
    os.chdir("..")
# Out:
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)
# ax = Axes(0.125,0.11;0.775x0.77)

# %%
os.chdir(folder_name)
os.system("ffmpeg -pattern_type glob -i '*.png' ez.gif")
os.system("ffmpeg -i ez.gif -movflags faststart -pix_fmt yuv420p -vf \"scale=trunc(iw/2)*2:trunc(ih/2)*2\" video.mp4")
os.chdir("..")
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '*.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 1920x1440 [SAR 11811:11811 DAR 4:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> gif (native))
# Press [q] to stop, [?] for help
# Output #0, gif, to 'ez.gif':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: gif, bgr8(pc, gbr/unknown/unknown, progressive), 1920x1440 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 100 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 gif
# frame=  120 fps= 19 q=-0.0 Lsize=   33626kB time=00:00:04.77 bitrate=57749.4kbits/s speed=0.737x
# video:33626kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000058%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, gif, from 'ez.gif':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: 57388 kb/s
#   Stream #0:0: Video: gif, bgra, 1920x1440 [SAR 64:64 DAR 4:3], 25 fps, 25 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e1f77f3e40] using SAR=1/1
# [libx264 @ 0x55e1f77f3e40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e1f77f3e40] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 0x55e1f77f3e40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1920x1440 [SAR 1:1 DAR 4:3], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [mp4 @ 0x55e1f77f2c40] Starting second pass: moving the moov atom to the beginning of the file
# frame=  120 fps= 27 q=-1.0 Lsize=    8348kB time=00:00:04.68 bitrate=14612.7kbits/s speed=1.04x
# video:8346kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.028235%
# [libx264 @ 0x55e1f77f3e40] frame I:1     Avg QP:22.97  size: 24164
# [libx264 @ 0x55e1f77f3e40] frame P:30    Avg QP:24.27  size:105627
# [libx264 @ 0x55e1f77f3e40] frame B:89    Avg QP:24.92  size: 60140
# [libx264 @ 0x55e1f77f3e40] consecutive B-frames:  0.8%  0.0%  2.5% 96.7%
# [libx264 @ 0x55e1f77f3e40] mb I  I16..4: 24.6% 69.0%  6.4%
# [libx264 @ 0x55e1f77f3e40] mb P  I16..4:  0.7%  9.6%  0.6%  P16..4:  7.0%  8.4%  6.1%  0.0%  0.0%    skip:67.7%
# [libx264 @ 0x55e1f77f3e40] mb B  I16..4:  0.2%  4.6%  0.1%  B16..8: 12.9%  3.6%  2.8%  direct: 4.2%  skip:71.6%  L0:48.0% L1:43.4% BI: 8.6%
# [libx264 @ 0x55e1f77f3e40] 8x8 transform intra:89.1% inter:53.6%
# [libx264 @ 0x55e1f77f3e40] coded y,uvDC,uvAC intra: 83.3% 66.7% 44.5% inter: 16.7% 4.4% 0.4%
# [libx264 @ 0x55e1f77f3e40] i16 v,h,dc,p: 54% 15% 13% 18%
# [libx264 @ 0x55e1f77f3e40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  4% 56%  4%  3%  4%  3%  3%  3%
# [libx264 @ 0x55e1f77f3e40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42%  9% 31%  4%  3%  4%  2%  3%  1%
# [libx264 @ 0x55e1f77f3e40] i8c dc,h,v,p: 48% 18% 18% 16%
# [libx264 @ 0x55e1f77f3e40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e1f77f3e40] ref P L0: 37.1% 10.7% 34.7% 17.5%
# [libx264 @ 0x55e1f77f3e40] ref B L0: 66.7% 25.2%  8.1%
# [libx264 @ 0x55e1f77f3e40] ref B L1: 85.3% 14.7%
# [libx264 @ 0x55e1f77f3e40] kb/s:14242.42

# %%
fig_rows = 3
fig_cols = 2
n_subplots = fig_rows * fig_cols
fig, ax = plt.subplots(
    fig_rows,
    fig_cols,
    figsize=(9, 12),
    sharex=False,
    sharey=True,
    )

with h5py.File(sim_path, 'r') as f:
    for k in range(n_subplots):
        i, j = int(k / fig_cols), (k % fig_cols)
        # i, j = (k % fig_rows), int(k / fig_rows)
        _ax = ax[i][j]
        ez_data = f['ez_data'][k]
        eps_data = f['eps_data'][:]
        elapsed = k * f.attrs['fs_delta']
        vmax = 0.6  # force consistent brightness
        plot_ez_data(ez_data, domain, ax=_ax, vmax=vmax, elapsed=elapsed)
        plot_eps_data(eps_data, domain, ax=_ax)
        plot_pml(pml_thickness, domain, ax=_ax)
# Out:
# ax = Axes(0.125,0.653529;0.352273x0.226471)
# ax = Axes(0.547727,0.653529;0.352273x0.226471)
# ax = Axes(0.125,0.381765;0.352273x0.226471)
# ax = Axes(0.547727,0.381765;0.352273x0.226471)
# ax = Axes(0.125,0.11;0.352273x0.226471)
# ax = Axes(0.547727,0.11;0.352273x0.226471)

# %%
# Grab final simulation snapshot without time-averaging
with h5py.File(sim_path, 'r') as f:
    final_snap = f['ez_data'][-1]

# Compute intensity as square of the complex amplitude
final_snap = np.abs(final_snap)**2

# Pick slices at different distances from the double slit
slice_dists = [10, 11, 12, 15, 20, 25]
slices = [final_snap[i * resolution] for i in slice_dists]
yarr = np.linspace(domain[2], domain[3], final_snap.shape[1])

# A rather involved plotting function
def plot_intensity(slice, yarr, ax1, ax2, vmax=None, xval=None, xlabel=False, ylabel=False):
    ax1.plot(yarr, slice)
    ax1.tick_params(axis='x', labelbottom=False)
    if ylabel:
        ax1.set_ylabel('$|E|^2$')
    else:
        ax1.tick_params('y', labelleft=False)
    if xval:
        ax1.annotate(
            f'x={xval}',
            xy=(1, 1),
            xytext=(-4, -4),
            xycoords='axes fraction',
            textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='top',
            )
    ax2.imshow(
        np.vstack(slice).T,
        cmap='inferno',
        aspect='auto',
        vmax=vmax,
        extent=[yarr[0], yarr[-1], 0, 1],
        )
    ax2.set_xlim([yarr[0], yarr[-1]])
    ax2.tick_params('y', labelleft=False)
    ax2.set_yticks([])
    if xlabel:
        ax2.set_xlabel('y (μm)')
    else:
        ax2.tick_params(axis='x', labelbottom=False)

fig, ax = plt.subplots(
    4, 3,
    figsize=(9, 6),
    gridspec_kw=dict(
        width_ratios=(4, 4, 4),
        height_ratios=(4, 1, 4, 1),
        wspace=0.12,
        hspace=0.1,
        ),
    sharex='col',
    sharey='row',
    )
for k, slice in enumerate(slices):
    i = 2 * int(k / 3)
    j = k % 3
    plot_intensity(
        slice, yarr, ax[i][j], ax[i+1][j],
        vmax=np.max(slices[:3]) if k < 3 else np.max(slices[3:]),
        xval=slice_dists[k],
        xlabel=(i==2),
        ylabel=(j==0))

# %%
# remove the h5 file
os.remove(sim_path)

# %% [markdown]
# # Reference
# ## Double Slits Simulation Tutorial
# https://humaticlabs.com/blog/meep-double-slit/
# ## FFmpeg Commands
# https://www.bannerbear.com/blog/how-to-make-gifs-from-images-using-ffmpeg/ <br>
# https://gist.github.com/gvoze32/95f96992a443e73c4794c342a44e0811
