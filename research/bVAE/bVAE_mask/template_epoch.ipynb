# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import copy
import random
import csv
import rings_utils

import torch
import torch.nn as nn
import torch.distributions as dist
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
# 設定亂數種子
seed = 42

torch.manual_seed(seed)           # 設定 CPU 的亂數種子
torch.cuda.manual_seed(seed)      # 設定當前 GPU 的亂數種子
torch.cuda.manual_seed_all(seed)  # 設定所有 GPU 的亂數種子
np.random.seed(seed)              # 設定 numpy 的亂數種子
random.seed(seed)                 # 設定 Python 的亂數種子
# 確保 cuDNN 使用確定性演算法
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# 查看當前路徑
print(f"Current Path: {os.getcwd()}")

# 設定資料路徑
base_dir = '../rings_generation'
file_name = 'rings(10k_512_10_50).csv'
file_path = os.path.join(base_dir, file_name)
print(f"File Path: {file_path}")
print("-"*60)

# 確保路徑存在
if not os.path.exists(file_path):
    raise FileNotFoundError(f"The file {file_path} does not exist.")

# 讀檔，將資料存入dataset
with open(file_path, 'r') as file:
    dataset = torch.tensor(
        [[float(value) for value in row] for row in csv.reader(file)],
        dtype=torch.float
    ).to(device)
print(f"Dataset Shape: {dataset.shape}")

# 將dataset分為training set跟testing set
total_size = len(dataset)
train_size = int(0.8 * total_size)
test_size = total_size - train_size
dataset_train, dataset_test = random_split(dataset=dataset, lengths=[train_size, test_size])

# 印出結果
print(f"Training Dataset Size: {len(dataset_train)}")
print(f"Testing Dataset Size: {len(dataset_test)}")
# Out:
# Current Path: /home/yihsin/Code/bVAE_mask
# File Path: ../rings_generation/rings(10k_512_10_50).csv
# ------------------------------------------------------------
# Dataset Shape: torch.Size([10000, 512])
# Training Dataset Size: 8000
# Testing Dataset Size: 2000

# %% [markdown]
# # 模型

# %% [markdown]
# gumbel softmax 的實現可以 PyTorch 已經用 RelaxedOneHotCategorical 包好了（之後改）

# %%
class CategoricalVAE(nn.Module):
    
    def __init__(self, input_layer, hidden_layers, N, K):
        
        super().__init__()

        self.N = N
        self.K = K
        
        # Encoder
        layer = []
        in_features = input_layer
        for out_features in hidden_layers:
            layer.append( nn.Linear(in_features, out_features) )
            layer.append( nn.ReLU() )
            in_features = out_features
        layer.append( nn.Linear(in_features, self.N*self.K) )
        self.encoder = nn.Sequential(*layer)
        
        # Decoder
        layer = []
        in_features = self.N*self.K
        for out_features in reversed(hidden_layers):
            layer.append( nn.Linear(in_features, out_features) )
            layer.append( nn.ReLU() )
            in_features = out_features
        layer.append( nn.Linear(in_features, input_layer) )
        layer.append( nn.Sigmoid() )
        self.decoder = nn.Sequential(*layer)
        
    def encode(self, inputs):
        '''
        input
        - inputs.shape: [batch_size, rings_size]
        output
        - logits.shape: [batch_size, N*K]
        '''
        logits = self.encoder(inputs)
        return logits

    def decode(self, latent_codes):
        '''
        input
        - latent_codes.shape: [batch_size, N*K]
        output
        - outputs.shape: [batch_size, rings_size]
        '''
        outputs = self.decoder(latent_codes)
        return outputs

    def gumbel_dist(self, shape, eps=1e-20):
        '''
        input
        - shape.shape: [batch_size, N*K]
        output
        - gumbel_noise.shape: [batch_size, N*K]
        '''
        U = torch.rand(shape).to(device)
        gumbel_noise = -torch.log(-torch.log(U + eps) + eps)
        return gumbel_noise

    def gumbel_softmax(self, logits, temperature):
        '''
        input
        - logits.shape: [batch_size, N*K]
        - temperature.shape: [1]
        output
        - latent_codes.shape: [batch_size, N*K]
        '''
        # Reshape to [batch_size*N, K]
        batch_size = len(logits)
        logits = logits.view(batch_size * self.N, self.K)
        gumbel_noise = self.gumbel_dist(logits.shape)
        y = logits + gumbel_noise
        latent_codes = nn.functional.softmax(y / temperature, dim=-1)

        # Reshape back to [batch_size, N*K]
        logits = logits.view(batch_size, self.N * self.K)
        latent_codes = latent_codes.view(batch_size, self.N * self.K)

        return latent_codes
    
    def forward(self, inputs, temperature):
        '''
        input
        - inputs.shape: [batch_size, rings_size]
        output
        - logits.shape: [batch_size, N*K]
        - latent_codes.shape: [batch_size, N*K]
        - outputs.shape: [batch_size, rings_size]
        '''
        logits = self.encode(inputs)
        latent_codes = self.gumbel_softmax(logits, temperature)
        outputs = self.decoder(latent_codes)
        return logits, latent_codes, outputs

# %% [markdown]
# # 訓練

# %%
batch_size = 100
epochs = 1000
learning_rate = 0.001

T_init = 1.0                                  # initial temperature
T_min = 0.5                                   # minimum temperature
# T_rate = -np.log(T_min / T_init) / (epochs * (1/2))     # 指數模型
# T_rate = (T_min - T_init) / (epochs * (1/2))            # 線性模型
T_rate = 0.0001
print(f"T_rate: {T_rate}")

K = 2     # number of classes
N = 64    # number of categorical distributions
# Out:
# T_rate: 0.0001

# %%
# DataLoader
dataloader_train = DataLoader(dataset=dataset_train,
                              batch_size=batch_size,
                              shuffle=False)

# %%
# Loss Function
def cat_kl_div(logits):
    '''
    input
    - logits.shape: [batch_size, N*K]
    output
    - kl_loss.shape: []
    '''
    # Reshape to [batch_size*N, K]
    batch_size = len(logits)
    logits = logits.view(batch_size*N, K)
    
    q = dist.Categorical(logits=logits)
    p = dist.Categorical(probs=torch.full(                     # p(z)假設為均勻分布
                                    size=(batch_size*N, K),
                                    fill_value=1.0/K,
                                    device=device
                                )
                        )
    kl = dist.kl.kl_divergence(q, p)    # kl.shape: [batch_size*N]
    kl_loss = torch.mean(kl)            # kl_loss.shape: []
    return kl_loss

def loss_func(outputs, labels, logits, alpha=1, beta=0, gamma=0):
    '''
    input
    - outputs.shape: [batch_size, rings_size]
    - labels.shape: [batch_size, rings_size]
    - logits.shape: [batch_size, N*K]
    output
    - kl_loss.shape: []
    - rec_loss.shape: []
    - loss.shape: []
    '''

    # 重構誤差
    rec_loss = nn.functional.binary_cross_entropy(outputs, labels, reduction="mean")

    # KL散度
    kl_loss = cat_kl_div(logits)

    # 總損失（乘上對應的係數）
    loss = alpha*rec_loss + beta*kl_loss
    
    return rec_loss, kl_loss, loss    # 返回的loss不包括alpha, beta, gamma，
                                      # 這樣才能準確比較這些係數不同時怎麼影響loss

# %%
model = CategoricalVAE(512, [300], N, K).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## 定義儲存、讀取權重的函數

# %%
def save_checkpoint(epoch, model, optimizer, path="./lucky/checkpoint_epoch_{}.pth"):
    '''
    epoch代表第幾個epoch
    '''
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, path.format(epoch))

# %%
def load_checkpoint(epoch, path="./lucky/checkpoint_batch_{}.pth"):
    checkpoint = torch.load(path.format(epoch))
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    return checkpoint['epoch']

# %% [markdown]
# ## 開始訓練

# %%
model.train()

# 給一個epoch存一次loss的用（應該要對epoch跟每個epoch的batch做平均）
avg_rec_loss = []
avg_kl_loss  = []
avg_loss     = []

# alpha, beta, gamma看要每個batch還是每個epoch存一次都可以
alpha_ls     = []
beta_ls      = []
gamma_ls     = []

# 設定初始溫度
temperature = T_init

for epoch in range(epochs):
    
    total_rec_loss = 0
    total_kl_loss  = 0
    total_loss     = 0
    
    for data in dataloader_train:
        '''
        data.shape: [batch_size, rings_size]
        '''

        # 清空梯度（會不會是這裡導致看到最前面一層的梯度都是0？）
        model.zero_grad()
        
        # 將讀到的data轉成model可以接受的inputs（這個case不用做任何轉變）
        inputs = data
        '''
        inputs.shape: [batch_size, rings_size]
        '''
        
        # 前向傳播
        logits, latent_codes, outputs = model(inputs, temperature)
        '''
        - logits.shape      : [batch_size, N*K]
        - latent_codes.shape: [batch_size, N*K]
        - outputs.shape     : [batch_size, rings_size]
        '''
        
        # 計算loss
        # (alpha, beta, gamma) = (1, 1, 1)
        rec_loss, kl_loss, loss = loss_func(    # 一個batch平均的loss
                                        outputs=outputs,
                                        labels=inputs,
                                        logits=logits,
                                    )
        total_rec_loss += rec_loss.item()
        total_kl_loss  += kl_loss.item()
        total_loss     += loss.item()
        
        # 反向傳播，計算梯度
        loss.backward()

        # 根據梯度更新參數
        optimizer.step()

    # 一個epoch保存一次權重
    save_checkpoint(epoch=epoch, model=model, optimizer=optimizer)
        
    # T_next = T_init * np.exp(-T_rate*(epoch+1))    # 指數模型
    # T_next = T_rate * epoch + T_init               # 線性模型
    # temperature = np.maximum(T_next, T_min)
    # print(f"{epoch+1:>3}. temperature: {temperature:.2f}")
    
    # 一個epoch平均的loss
    avg_rec_loss.append( total_rec_loss / len(dataloader_train) )
    avg_kl_loss.append( total_kl_loss / len(dataloader_train) )
    avg_loss.append( total_loss / len(dataloader_train) )
    print(f"{epoch+1:>3}. " \
          f"avg_loss: {avg_loss[epoch]:.7f}, " \
          f"avg_rec_loss: {avg_rec_loss[epoch]:.7f}, " \
          f"avg_kl_loss: {avg_kl_loss[epoch]:.7f}")
# Out:
#   1. avg_loss: 0.6553526, avg_rec_loss: 0.6553526, avg_kl_loss: 0.2643824
#   2. avg_loss: 0.5247140, avg_rec_loss: 0.5247140, avg_kl_loss: 0.4698584
#   3. avg_loss: 0.4528063, avg_rec_loss: 0.4528063, avg_kl_loss: 0.4992649
#   4. avg_loss: 0.4122256, avg_rec_loss: 0.4122256, avg_kl_loss: 0.5117011
#   5. avg_loss: 0.3864416, avg_rec_loss: 0.3864416, avg_kl_loss: 0.5187230
#   6. avg_loss: 0.3641384, avg_rec_loss: 0.3641384, avg_kl_loss: 0.5236051
#   7. avg_loss: 0.3432265, avg_rec_loss: 0.3432265, avg_kl_loss: 0.5278263
#   8. avg_loss: 0.3327938, avg_rec_loss: 0.3327938, avg_kl_loss: 0.5309847
#   9. avg_loss: 0.3229965, avg_rec_loss: 0.3229965, avg_kl_loss: 0.5327137
#  10. avg_loss: 0.3127981, avg_rec_loss: 0.3127981, avg_kl_loss: 0.5343523
#  11. avg_loss: 0.3047299, avg_rec_loss: 0.3047299, avg_kl_loss: 0.5361022
#  12. avg_loss: 0.2986958, avg_rec_loss: 0.2986958, avg_kl_loss: 0.5375714
#  13. avg_loss: 0.2938604, avg_rec_loss: 0.2938604, avg_kl_loss: 0.5387168
#  14. avg_loss: 0.2881501, avg_rec_loss: 0.2881501, avg_kl_loss: 0.5396874
#  15. avg_loss: 0.2823679, avg_rec_loss: 0.2823679, avg_kl_loss: 0.5401388
#  16. avg_loss: 0.2779005, avg_rec_loss: 0.2779005, avg_kl_loss: 0.5410695
#  17. avg_loss: 0.2743105, avg_rec_loss: 0.2743105, avg_kl_loss: 0.5423258
#  18. avg_loss: 0.2715997, avg_rec_loss: 0.2715997, avg_kl_loss: 0.5431800
#  19. avg_loss: 0.2690661, avg_rec_loss: 0.2690661, avg_kl_loss: 0.5441735
#  20. avg_loss: 0.2676426, avg_rec_loss: 0.2676426, avg_kl_loss: 0.5447042
#  21. avg_loss: 0.2653238, avg_rec_loss: 0.2653238, avg_kl_loss: 0.5458723
#  22. avg_loss: 0.2653555, avg_rec_loss: 0.2653555, avg_kl_loss: 0.5460514
#  23. avg_loss: 0.2641512, avg_rec_loss: 0.2641512, avg_kl_loss: 0.5466144
#  24. avg_loss: 0.2625750, avg_rec_loss: 0.2625750, avg_kl_loss: 0.5477571
#  25. avg_loss: 0.2614101, avg_rec_loss: 0.2614101, avg_kl_loss: 0.5481882
#  26. avg_loss: 0.2599406, avg_rec_loss: 0.2599406, avg_kl_loss: 0.5484772
#  27. avg_loss: 0.2582778, avg_rec_loss: 0.2582778, avg_kl_loss: 0.5490869
#  28. avg_loss: 0.2568781, avg_rec_loss: 0.2568781, avg_kl_loss: 0.5496233
#  29. avg_loss: 0.2563096, avg_rec_loss: 0.2563096, avg_kl_loss: 0.5498358
#  30. avg_loss: 0.2540648, avg_rec_loss: 0.2540648, avg_kl_loss: 0.5500291
#  31. avg_loss: 0.2527823, avg_rec_loss: 0.2527823, avg_kl_loss: 0.5504126
#  32. avg_loss: 0.2522317, avg_rec_loss: 0.2522317, avg_kl_loss: 0.5511205
#  33. avg_loss: 0.2503665, avg_rec_loss: 0.2503665, avg_kl_loss: 0.5518973
#  34. avg_loss: 0.2499693, avg_rec_loss: 0.2499693, avg_kl_loss: 0.5522226
#  35. avg_loss: 0.2488801, avg_rec_loss: 0.2488801, avg_kl_loss: 0.5528299
#  36. avg_loss: 0.2480559, avg_rec_loss: 0.2480559, avg_kl_loss: 0.5530621
#  37. avg_loss: 0.2481621, avg_rec_loss: 0.2481621, avg_kl_loss: 0.5530050
#  38. avg_loss: 0.2475139, avg_rec_loss: 0.2475139, avg_kl_loss: 0.5537512
#  39. avg_loss: 0.2476427, avg_rec_loss: 0.2476427, avg_kl_loss: 0.5540892
#  40. avg_loss: 0.2466684, avg_rec_loss: 0.2466684, avg_kl_loss: 0.5543051
#  41. avg_loss: 0.2454461, avg_rec_loss: 0.2454461, avg_kl_loss: 0.5547716
#  42. avg_loss: 0.2450674, avg_rec_loss: 0.2450674, avg_kl_loss: 0.5551653
#  43. avg_loss: 0.2445443, avg_rec_loss: 0.2445443, avg_kl_loss: 0.5554440
#  44. avg_loss: 0.2439691, avg_rec_loss: 0.2439691, avg_kl_loss: 0.5557424
#  45. avg_loss: 0.2438944, avg_rec_loss: 0.2438944, avg_kl_loss: 0.5560555
#  46. avg_loss: 0.2425826, avg_rec_loss: 0.2425826, avg_kl_loss: 0.5561304
#  47. avg_loss: 0.2427719, avg_rec_loss: 0.2427719, avg_kl_loss: 0.5566740
#  48. avg_loss: 0.2422588, avg_rec_loss: 0.2422588, avg_kl_loss: 0.5571688
#  49. avg_loss: 0.2414160, avg_rec_loss: 0.2414160, avg_kl_loss: 0.5575812
#  50. avg_loss: 0.2404532, avg_rec_loss: 0.2404532, avg_kl_loss: 0.5581056
#  51. avg_loss: 0.2407538, avg_rec_loss: 0.2407538, avg_kl_loss: 0.5580558
#  52. avg_loss: 0.2402211, avg_rec_loss: 0.2402211, avg_kl_loss: 0.5585935
#  53. avg_loss: 0.2396202, avg_rec_loss: 0.2396202, avg_kl_loss: 0.5589053
#  54. avg_loss: 0.2393065, avg_rec_loss: 0.2393065, avg_kl_loss: 0.5592393
#  55. avg_loss: 0.2385480, avg_rec_loss: 0.2385480, avg_kl_loss: 0.5595458
#  56. avg_loss: 0.2374880, avg_rec_loss: 0.2374880, avg_kl_loss: 0.5601040
#  57. avg_loss: 0.2367740, avg_rec_loss: 0.2367740, avg_kl_loss: 0.5598747
#  58. avg_loss: 0.2355510, avg_rec_loss: 0.2355510, avg_kl_loss: 0.5604324
#  59. avg_loss: 0.2353962, avg_rec_loss: 0.2353962, avg_kl_loss: 0.5607366
#  60. avg_loss: 0.2349653, avg_rec_loss: 0.2349653, avg_kl_loss: 0.5612940
#  61. avg_loss: 0.2347778, avg_rec_loss: 0.2347778, avg_kl_loss: 0.5607863
#  62. avg_loss: 0.2330211, avg_rec_loss: 0.2330211, avg_kl_loss: 0.5612855
#  63. avg_loss: 0.2329784, avg_rec_loss: 0.2329784, avg_kl_loss: 0.5613696
#  64. avg_loss: 0.2324358, avg_rec_loss: 0.2324358, avg_kl_loss: 0.5617408
#  65. avg_loss: 0.2321054, avg_rec_loss: 0.2321054, avg_kl_loss: 0.5619336
#  66. avg_loss: 0.2318709, avg_rec_loss: 0.2318709, avg_kl_loss: 0.5621816
#  67. avg_loss: 0.2307064, avg_rec_loss: 0.2307064, avg_kl_loss: 0.5625063
#  68. avg_loss: 0.2307372, avg_rec_loss: 0.2307372, avg_kl_loss: 0.5626751
#  69. avg_loss: 0.2301847, avg_rec_loss: 0.2301847, avg_kl_loss: 0.5628742
#  70. avg_loss: 0.2291830, avg_rec_loss: 0.2291830, avg_kl_loss: 0.5632980
#  71. avg_loss: 0.2286558, avg_rec_loss: 0.2286558, avg_kl_loss: 0.5637551
#  72. avg_loss: 0.2286750, avg_rec_loss: 0.2286750, avg_kl_loss: 0.5634166
#  73. avg_loss: 0.2282237, avg_rec_loss: 0.2282237, avg_kl_loss: 0.5636101
#  74. avg_loss: 0.2275313, avg_rec_loss: 0.2275313, avg_kl_loss: 0.5639944
#  75. avg_loss: 0.2269666, avg_rec_loss: 0.2269666, avg_kl_loss: 0.5643592
#  76. avg_loss: 0.2271655, avg_rec_loss: 0.2271655, avg_kl_loss: 0.5645376
#  77. avg_loss: 0.2262672, avg_rec_loss: 0.2262672, avg_kl_loss: 0.5650118
#  78. avg_loss: 0.2252619, avg_rec_loss: 0.2252619, avg_kl_loss: 0.5646850
#  79. avg_loss: 0.2257531, avg_rec_loss: 0.2257531, avg_kl_loss: 0.5649199
#  80. avg_loss: 0.2259853, avg_rec_loss: 0.2259853, avg_kl_loss: 0.5650665
#  81. avg_loss: 0.2250001, avg_rec_loss: 0.2250001, avg_kl_loss: 0.5654685
#  82. avg_loss: 0.2245921, avg_rec_loss: 0.2245921, avg_kl_loss: 0.5655886
#  83. avg_loss: 0.2241549, avg_rec_loss: 0.2241549, avg_kl_loss: 0.5664074
#  84. avg_loss: 0.2238843, avg_rec_loss: 0.2238843, avg_kl_loss: 0.5666530
#  85. avg_loss: 0.2236304, avg_rec_loss: 0.2236304, avg_kl_loss: 0.5669986
#  86. avg_loss: 0.2229108, avg_rec_loss: 0.2229108, avg_kl_loss: 0.5670989
#  87. avg_loss: 0.2220081, avg_rec_loss: 0.2220081, avg_kl_loss: 0.5668966
#  88. avg_loss: 0.2217802, avg_rec_loss: 0.2217802, avg_kl_loss: 0.5672311
#  89. avg_loss: 0.2219379, avg_rec_loss: 0.2219379, avg_kl_loss: 0.5684084
#  90. avg_loss: 0.2215327, avg_rec_loss: 0.2215327, avg_kl_loss: 0.5681709
#  91. avg_loss: 0.2208948, avg_rec_loss: 0.2208948, avg_kl_loss: 0.5681646
#  92. avg_loss: 0.2204216, avg_rec_loss: 0.2204216, avg_kl_loss: 0.5682867
#  93. avg_loss: 0.2198282, avg_rec_loss: 0.2198282, avg_kl_loss: 0.5683495
#  94. avg_loss: 0.2199141, avg_rec_loss: 0.2199141, avg_kl_loss: 0.5685824
#  95. avg_loss: 0.2198556, avg_rec_loss: 0.2198556, avg_kl_loss: 0.5692354
#  96. avg_loss: 0.2194805, avg_rec_loss: 0.2194805, avg_kl_loss: 0.5693082
#  97. avg_loss: 0.2189389, avg_rec_loss: 0.2189389, avg_kl_loss: 0.5691873
#  98. avg_loss: 0.2181905, avg_rec_loss: 0.2181905, avg_kl_loss: 0.5694405
#  99. avg_loss: 0.2191149, avg_rec_loss: 0.2191149, avg_kl_loss: 0.5693624
# 100. avg_loss: 0.2180338, avg_rec_loss: 0.2180338, avg_kl_loss: 0.5699127
# 101. avg_loss: 0.2175295, avg_rec_loss: 0.2175295, avg_kl_loss: 0.5700464
# 102. avg_loss: 0.2171354, avg_rec_loss: 0.2171354, avg_kl_loss: 0.5703160
# 103. avg_loss: 0.2170583, avg_rec_loss: 0.2170583, avg_kl_loss: 0.5710163
# 104. avg_loss: 0.2163393, avg_rec_loss: 0.2163393, avg_kl_loss: 0.5711500
# 105. avg_loss: 0.2160444, avg_rec_loss: 0.2160444, avg_kl_loss: 0.5712692
# 106. avg_loss: 0.2162937, avg_rec_loss: 0.2162937, avg_kl_loss: 0.5715151
# 107. avg_loss: 0.2159455, avg_rec_loss: 0.2159455, avg_kl_loss: 0.5717123
# 108. avg_loss: 0.2157778, avg_rec_loss: 0.2157778, avg_kl_loss: 0.5715256
# 109. avg_loss: 0.2151496, avg_rec_loss: 0.2151496, avg_kl_loss: 0.5721681
# 110. avg_loss: 0.2154055, avg_rec_loss: 0.2154055, avg_kl_loss: 0.5727362
# 111. avg_loss: 0.2151122, avg_rec_loss: 0.2151122, avg_kl_loss: 0.5728343
# 112. avg_loss: 0.2143550, avg_rec_loss: 0.2143550, avg_kl_loss: 0.5734352
# 113. avg_loss: 0.2144602, avg_rec_loss: 0.2144602, avg_kl_loss: 0.5737525
# 114. avg_loss: 0.2132257, avg_rec_loss: 0.2132257, avg_kl_loss: 0.5739789
# 115. avg_loss: 0.2134230, avg_rec_loss: 0.2134230, avg_kl_loss: 0.5737724
# 116. avg_loss: 0.2139217, avg_rec_loss: 0.2139217, avg_kl_loss: 0.5741397
# 117. avg_loss: 0.2130868, avg_rec_loss: 0.2130868, avg_kl_loss: 0.5742649
# 118. avg_loss: 0.2123336, avg_rec_loss: 0.2123336, avg_kl_loss: 0.5743346
# 119. avg_loss: 0.2132823, avg_rec_loss: 0.2132823, avg_kl_loss: 0.5747380
# 120. avg_loss: 0.2127172, avg_rec_loss: 0.2127172, avg_kl_loss: 0.5748165
# 121. avg_loss: 0.2125645, avg_rec_loss: 0.2125645, avg_kl_loss: 0.5750055
# 122. avg_loss: 0.2115340, avg_rec_loss: 0.2115340, avg_kl_loss: 0.5757342
# 123. avg_loss: 0.2109289, avg_rec_loss: 0.2109289, avg_kl_loss: 0.5758106
# 124. avg_loss: 0.2113036, avg_rec_loss: 0.2113036, avg_kl_loss: 0.5755215
# 125. avg_loss: 0.2114435, avg_rec_loss: 0.2114435, avg_kl_loss: 0.5761013
# 126. avg_loss: 0.2110298, avg_rec_loss: 0.2110298, avg_kl_loss: 0.5761294
# 127. avg_loss: 0.2112900, avg_rec_loss: 0.2112900, avg_kl_loss: 0.5769667
# 128. avg_loss: 0.2109892, avg_rec_loss: 0.2109892, avg_kl_loss: 0.5771000
# 129. avg_loss: 0.2099420, avg_rec_loss: 0.2099420, avg_kl_loss: 0.5770612
# 130. avg_loss: 0.2101181, avg_rec_loss: 0.2101181, avg_kl_loss: 0.5775947
# 131. avg_loss: 0.2100457, avg_rec_loss: 0.2100457, avg_kl_loss: 0.5779893
# 132. avg_loss: 0.2095449, avg_rec_loss: 0.2095449, avg_kl_loss: 0.5778570
# 133. avg_loss: 0.2098204, avg_rec_loss: 0.2098204, avg_kl_loss: 0.5785077
# 134. avg_loss: 0.2091515, avg_rec_loss: 0.2091515, avg_kl_loss: 0.5788859
# 135. avg_loss: 0.2080131, avg_rec_loss: 0.2080131, avg_kl_loss: 0.5787617
# 136. avg_loss: 0.2085407, avg_rec_loss: 0.2085407, avg_kl_loss: 0.5790965
# 137. avg_loss: 0.2085155, avg_rec_loss: 0.2085155, avg_kl_loss: 0.5792868
# 138. avg_loss: 0.2087182, avg_rec_loss: 0.2087182, avg_kl_loss: 0.5795261
# 139. avg_loss: 0.2080632, avg_rec_loss: 0.2080632, avg_kl_loss: 0.5797116
# 140. avg_loss: 0.2081413, avg_rec_loss: 0.2081413, avg_kl_loss: 0.5802716
# 141. avg_loss: 0.2075823, avg_rec_loss: 0.2075823, avg_kl_loss: 0.5801060
# 142. avg_loss: 0.2071861, avg_rec_loss: 0.2071861, avg_kl_loss: 0.5802456
# 143. avg_loss: 0.2071396, avg_rec_loss: 0.2071396, avg_kl_loss: 0.5806210
# 144. avg_loss: 0.2077260, avg_rec_loss: 0.2077260, avg_kl_loss: 0.5809497
# 145. avg_loss: 0.2069239, avg_rec_loss: 0.2069239, avg_kl_loss: 0.5811948
# 146. avg_loss: 0.2062714, avg_rec_loss: 0.2062714, avg_kl_loss: 0.5814121
# 147. avg_loss: 0.2066189, avg_rec_loss: 0.2066189, avg_kl_loss: 0.5821360
# 148. avg_loss: 0.2063271, avg_rec_loss: 0.2063271, avg_kl_loss: 0.5817855
# 149. avg_loss: 0.2052040, avg_rec_loss: 0.2052040, avg_kl_loss: 0.5826430
# 150. avg_loss: 0.2060588, avg_rec_loss: 0.2060588, avg_kl_loss: 0.5829030
# 151. avg_loss: 0.2053329, avg_rec_loss: 0.2053329, avg_kl_loss: 0.5827890
# 152. avg_loss: 0.2052556, avg_rec_loss: 0.2052556, avg_kl_loss: 0.5829314
# 153. avg_loss: 0.2052631, avg_rec_loss: 0.2052631, avg_kl_loss: 0.5830466
# 154. avg_loss: 0.2044819, avg_rec_loss: 0.2044819, avg_kl_loss: 0.5831469
# 155. avg_loss: 0.2042718, avg_rec_loss: 0.2042718, avg_kl_loss: 0.5835555
# 156. avg_loss: 0.2040644, avg_rec_loss: 0.2040644, avg_kl_loss: 0.5833245
# 157. avg_loss: 0.2043216, avg_rec_loss: 0.2043216, avg_kl_loss: 0.5834325
# 158. avg_loss: 0.2042277, avg_rec_loss: 0.2042277, avg_kl_loss: 0.5838558
# 159. avg_loss: 0.2037582, avg_rec_loss: 0.2037582, avg_kl_loss: 0.5840284
# 160. avg_loss: 0.2036673, avg_rec_loss: 0.2036673, avg_kl_loss: 0.5845788
# 161. avg_loss: 0.2035359, avg_rec_loss: 0.2035359, avg_kl_loss: 0.5845660
# 162. avg_loss: 0.2028028, avg_rec_loss: 0.2028028, avg_kl_loss: 0.5846802
# 163. avg_loss: 0.2029117, avg_rec_loss: 0.2029117, avg_kl_loss: 0.5849225
# 164. avg_loss: 0.2018413, avg_rec_loss: 0.2018413, avg_kl_loss: 0.5851297
# 165. avg_loss: 0.2023619, avg_rec_loss: 0.2023619, avg_kl_loss: 0.5853883
# 166. avg_loss: 0.2021072, avg_rec_loss: 0.2021072, avg_kl_loss: 0.5854587
# 167. avg_loss: 0.2013376, avg_rec_loss: 0.2013376, avg_kl_loss: 0.5857547
# 168. avg_loss: 0.2023490, avg_rec_loss: 0.2023490, avg_kl_loss: 0.5857209
# 169. avg_loss: 0.2016966, avg_rec_loss: 0.2016966, avg_kl_loss: 0.5860113
# 170. avg_loss: 0.2015065, avg_rec_loss: 0.2015065, avg_kl_loss: 0.5861376
# 171. avg_loss: 0.2014907, avg_rec_loss: 0.2014907, avg_kl_loss: 0.5864585
# 172. avg_loss: 0.2008247, avg_rec_loss: 0.2008247, avg_kl_loss: 0.5865842
# 173. avg_loss: 0.2013541, avg_rec_loss: 0.2013541, avg_kl_loss: 0.5869379
# 174. avg_loss: 0.2009354, avg_rec_loss: 0.2009354, avg_kl_loss: 0.5869042
# 175. avg_loss: 0.2006283, avg_rec_loss: 0.2006283, avg_kl_loss: 0.5868710
# 176. avg_loss: 0.2007209, avg_rec_loss: 0.2007209, avg_kl_loss: 0.5874505
# 177. avg_loss: 0.2004027, avg_rec_loss: 0.2004027, avg_kl_loss: 0.5874441
# 178. avg_loss: 0.2002706, avg_rec_loss: 0.2002706, avg_kl_loss: 0.5876904
# 179. avg_loss: 0.2003943, avg_rec_loss: 0.2003943, avg_kl_loss: 0.5879854
# 180. avg_loss: 0.2003139, avg_rec_loss: 0.2003139, avg_kl_loss: 0.5881677
# 181. avg_loss: 0.1995294, avg_rec_loss: 0.1995294, avg_kl_loss: 0.5883918
# 182. avg_loss: 0.1997563, avg_rec_loss: 0.1997563, avg_kl_loss: 0.5885699
# 183. avg_loss: 0.1994612, avg_rec_loss: 0.1994612, avg_kl_loss: 0.5890565
# 184. avg_loss: 0.1998825, avg_rec_loss: 0.1998825, avg_kl_loss: 0.5889965
# 185. avg_loss: 0.1990913, avg_rec_loss: 0.1990913, avg_kl_loss: 0.5891790
# 186. avg_loss: 0.1994395, avg_rec_loss: 0.1994395, avg_kl_loss: 0.5894379
# 187. avg_loss: 0.1993994, avg_rec_loss: 0.1993994, avg_kl_loss: 0.5899006
# 188. avg_loss: 0.1990110, avg_rec_loss: 0.1990110, avg_kl_loss: 0.5900366
# 189. avg_loss: 0.1985768, avg_rec_loss: 0.1985768, avg_kl_loss: 0.5903362
# 190. avg_loss: 0.1987540, avg_rec_loss: 0.1987540, avg_kl_loss: 0.5906018
# 191. avg_loss: 0.1981941, avg_rec_loss: 0.1981941, avg_kl_loss: 0.5909088
# 192. avg_loss: 0.1979894, avg_rec_loss: 0.1979894, avg_kl_loss: 0.5912936
# 193. avg_loss: 0.1977127, avg_rec_loss: 0.1977127, avg_kl_loss: 0.5910612
# 194. avg_loss: 0.1987647, avg_rec_loss: 0.1987647, avg_kl_loss: 0.5909103
# 195. avg_loss: 0.1980055, avg_rec_loss: 0.1980055, avg_kl_loss: 0.5911849
# 196. avg_loss: 0.1980906, avg_rec_loss: 0.1980906, avg_kl_loss: 0.5916385
# 197. avg_loss: 0.1980643, avg_rec_loss: 0.1980643, avg_kl_loss: 0.5921426
# 198. avg_loss: 0.1974191, avg_rec_loss: 0.1974191, avg_kl_loss: 0.5922488
# 199. avg_loss: 0.1973736, avg_rec_loss: 0.1973736, avg_kl_loss: 0.5920402
# 200. avg_loss: 0.1967942, avg_rec_loss: 0.1967942, avg_kl_loss: 0.5926065
# 201. avg_loss: 0.1970931, avg_rec_loss: 0.1970931, avg_kl_loss: 0.5929215
# 202. avg_loss: 0.1974763, avg_rec_loss: 0.1974763, avg_kl_loss: 0.5929189
# 203. avg_loss: 0.1975982, avg_rec_loss: 0.1975982, avg_kl_loss: 0.5930547
# 204. avg_loss: 0.1972740, avg_rec_loss: 0.1972740, avg_kl_loss: 0.5933680
# 205. avg_loss: 0.1964806, avg_rec_loss: 0.1964806, avg_kl_loss: 0.5937104
# 206. avg_loss: 0.1966911, avg_rec_loss: 0.1966911, avg_kl_loss: 0.5938205
# 207. avg_loss: 0.1960331, avg_rec_loss: 0.1960331, avg_kl_loss: 0.5938671
# 208. avg_loss: 0.1960992, avg_rec_loss: 0.1960992, avg_kl_loss: 0.5941291
# 209. avg_loss: 0.1964078, avg_rec_loss: 0.1964078, avg_kl_loss: 0.5946883
# 210. avg_loss: 0.1961280, avg_rec_loss: 0.1961280, avg_kl_loss: 0.5947107
# 211. avg_loss: 0.1958122, avg_rec_loss: 0.1958122, avg_kl_loss: 0.5949067
# 212. avg_loss: 0.1964764, avg_rec_loss: 0.1964764, avg_kl_loss: 0.5948172
# 213. avg_loss: 0.1951851, avg_rec_loss: 0.1951851, avg_kl_loss: 0.5950563
# 214. avg_loss: 0.1960251, avg_rec_loss: 0.1960251, avg_kl_loss: 0.5953259
# 215. avg_loss: 0.1959200, avg_rec_loss: 0.1959200, avg_kl_loss: 0.5956041
# 216. avg_loss: 0.1956906, avg_rec_loss: 0.1956906, avg_kl_loss: 0.5960241
# 217. avg_loss: 0.1950733, avg_rec_loss: 0.1950733, avg_kl_loss: 0.5961996
# 218. avg_loss: 0.1960219, avg_rec_loss: 0.1960219, avg_kl_loss: 0.5961117
# 219. avg_loss: 0.1954100, avg_rec_loss: 0.1954100, avg_kl_loss: 0.5961720
# 220. avg_loss: 0.1958227, avg_rec_loss: 0.1958227, avg_kl_loss: 0.5964088
# 221. avg_loss: 0.1957039, avg_rec_loss: 0.1957039, avg_kl_loss: 0.5968361
# 222. avg_loss: 0.1956129, avg_rec_loss: 0.1956129, avg_kl_loss: 0.5970215
# 223. avg_loss: 0.1950128, avg_rec_loss: 0.1950128, avg_kl_loss: 0.5970664
# 224. avg_loss: 0.1951195, avg_rec_loss: 0.1951195, avg_kl_loss: 0.5972170
# 225. avg_loss: 0.1945997, avg_rec_loss: 0.1945997, avg_kl_loss: 0.5976648
# 226. avg_loss: 0.1949923, avg_rec_loss: 0.1949923, avg_kl_loss: 0.5980061
# 227. avg_loss: 0.1942985, avg_rec_loss: 0.1942985, avg_kl_loss: 0.5982437
# 228. avg_loss: 0.1943673, avg_rec_loss: 0.1943673, avg_kl_loss: 0.5985759
# 229. avg_loss: 0.1947374, avg_rec_loss: 0.1947374, avg_kl_loss: 0.5988227
# 230. avg_loss: 0.1947159, avg_rec_loss: 0.1947159, avg_kl_loss: 0.5990826
# 231. avg_loss: 0.1953204, avg_rec_loss: 0.1953204, avg_kl_loss: 0.5989508
# 232. avg_loss: 0.1944822, avg_rec_loss: 0.1944822, avg_kl_loss: 0.5994746
# 233. avg_loss: 0.1952433, avg_rec_loss: 0.1952433, avg_kl_loss: 0.5990385
# 234. avg_loss: 0.1946378, avg_rec_loss: 0.1946378, avg_kl_loss: 0.5996987
# 235. avg_loss: 0.1948939, avg_rec_loss: 0.1948939, avg_kl_loss: 0.5998931
# 236. avg_loss: 0.1946255, avg_rec_loss: 0.1946255, avg_kl_loss: 0.6001522
# 237. avg_loss: 0.1946056, avg_rec_loss: 0.1946056, avg_kl_loss: 0.6003629
# 238. avg_loss: 0.1949389, avg_rec_loss: 0.1949389, avg_kl_loss: 0.6011469
# 239. avg_loss: 0.1941566, avg_rec_loss: 0.1941566, avg_kl_loss: 0.6011467
# 240. avg_loss: 0.1944873, avg_rec_loss: 0.1944873, avg_kl_loss: 0.6011265
# 241. avg_loss: 0.1937329, avg_rec_loss: 0.1937329, avg_kl_loss: 0.6015378
# 242. avg_loss: 0.1936001, avg_rec_loss: 0.1936001, avg_kl_loss: 0.6016317
# 243. avg_loss: 0.1934072, avg_rec_loss: 0.1934072, avg_kl_loss: 0.6015348
# 244. avg_loss: 0.1938670, avg_rec_loss: 0.1938670, avg_kl_loss: 0.6017804
# 245. avg_loss: 0.1938806, avg_rec_loss: 0.1938806, avg_kl_loss: 0.6021281
# 246. avg_loss: 0.1933787, avg_rec_loss: 0.1933787, avg_kl_loss: 0.6025424
# 247. avg_loss: 0.1937646, avg_rec_loss: 0.1937646, avg_kl_loss: 0.6030013
# 248. avg_loss: 0.1931066, avg_rec_loss: 0.1931066, avg_kl_loss: 0.6032230
# 249. avg_loss: 0.1927642, avg_rec_loss: 0.1927642, avg_kl_loss: 0.6031378
# 250. avg_loss: 0.1922235, avg_rec_loss: 0.1922235, avg_kl_loss: 0.6033927
# 251. avg_loss: 0.1925629, avg_rec_loss: 0.1925629, avg_kl_loss: 0.6038273
# 252. avg_loss: 0.1926480, avg_rec_loss: 0.1926480, avg_kl_loss: 0.6035549
# 253. avg_loss: 0.1921254, avg_rec_loss: 0.1921254, avg_kl_loss: 0.6037874
# 254. avg_loss: 0.1922452, avg_rec_loss: 0.1922452, avg_kl_loss: 0.6040382
# 255. avg_loss: 0.1915243, avg_rec_loss: 0.1915243, avg_kl_loss: 0.6039660
# 256. avg_loss: 0.1916952, avg_rec_loss: 0.1916952, avg_kl_loss: 0.6045342
# 257. avg_loss: 0.1923924, avg_rec_loss: 0.1923924, avg_kl_loss: 0.6042921
# 258. avg_loss: 0.1917542, avg_rec_loss: 0.1917542, avg_kl_loss: 0.6041767
# 259. avg_loss: 0.1923044, avg_rec_loss: 0.1923044, avg_kl_loss: 0.6046283
# 260. avg_loss: 0.1914169, avg_rec_loss: 0.1914169, avg_kl_loss: 0.6051788
# 261. avg_loss: 0.1909078, avg_rec_loss: 0.1909078, avg_kl_loss: 0.6051091
# 262. avg_loss: 0.1906919, avg_rec_loss: 0.1906919, avg_kl_loss: 0.6054801
# 263. avg_loss: 0.1908859, avg_rec_loss: 0.1908859, avg_kl_loss: 0.6056661
# 264. avg_loss: 0.1904450, avg_rec_loss: 0.1904450, avg_kl_loss: 0.6054943
# 265. avg_loss: 0.1904732, avg_rec_loss: 0.1904732, avg_kl_loss: 0.6056641
# 266. avg_loss: 0.1910476, avg_rec_loss: 0.1910476, avg_kl_loss: 0.6058041
# 267. avg_loss: 0.1904981, avg_rec_loss: 0.1904981, avg_kl_loss: 0.6061408
# 268. avg_loss: 0.1903759, avg_rec_loss: 0.1903759, avg_kl_loss: 0.6060360
# 269. avg_loss: 0.1896668, avg_rec_loss: 0.1896668, avg_kl_loss: 0.6062138
# 270. avg_loss: 0.1890254, avg_rec_loss: 0.1890254, avg_kl_loss: 0.6065600
# 271. avg_loss: 0.1895067, avg_rec_loss: 0.1895067, avg_kl_loss: 0.6067598
# 272. avg_loss: 0.1889857, avg_rec_loss: 0.1889857, avg_kl_loss: 0.6067449
# 273. avg_loss: 0.1891593, avg_rec_loss: 0.1891593, avg_kl_loss: 0.6069007
# 274. avg_loss: 0.1890767, avg_rec_loss: 0.1890767, avg_kl_loss: 0.6069096
# 275. avg_loss: 0.1889937, avg_rec_loss: 0.1889937, avg_kl_loss: 0.6070213
# 276. avg_loss: 0.1891978, avg_rec_loss: 0.1891978, avg_kl_loss: 0.6074688
# 277. avg_loss: 0.1895415, avg_rec_loss: 0.1895415, avg_kl_loss: 0.6074301
# 278. avg_loss: 0.1890553, avg_rec_loss: 0.1890553, avg_kl_loss: 0.6077062
# 279. avg_loss: 0.1886277, avg_rec_loss: 0.1886277, avg_kl_loss: 0.6077073
# 280. avg_loss: 0.1885986, avg_rec_loss: 0.1885986, avg_kl_loss: 0.6081991
# 281. avg_loss: 0.1884451, avg_rec_loss: 0.1884451, avg_kl_loss: 0.6081675
# 282. avg_loss: 0.1887157, avg_rec_loss: 0.1887157, avg_kl_loss: 0.6082457
# 283. avg_loss: 0.1893146, avg_rec_loss: 0.1893146, avg_kl_loss: 0.6084277
# 284. avg_loss: 0.1881943, avg_rec_loss: 0.1881943, avg_kl_loss: 0.6087560
# 285. avg_loss: 0.1873984, avg_rec_loss: 0.1873984, avg_kl_loss: 0.6091276
# 286. avg_loss: 0.1887741, avg_rec_loss: 0.1887741, avg_kl_loss: 0.6090879
# 287. avg_loss: 0.1875231, avg_rec_loss: 0.1875231, avg_kl_loss: 0.6089947
# 288. avg_loss: 0.1875022, avg_rec_loss: 0.1875022, avg_kl_loss: 0.6092725
# 289. avg_loss: 0.1875641, avg_rec_loss: 0.1875641, avg_kl_loss: 0.6089611
# 290. avg_loss: 0.1875354, avg_rec_loss: 0.1875354, avg_kl_loss: 0.6093137
# 291. avg_loss: 0.1881247, avg_rec_loss: 0.1881247, avg_kl_loss: 0.6095679
# 292. avg_loss: 0.1885093, avg_rec_loss: 0.1885093, avg_kl_loss: 0.6096054
# 293. avg_loss: 0.1884237, avg_rec_loss: 0.1884237, avg_kl_loss: 0.6097904
# 294. avg_loss: 0.1872853, avg_rec_loss: 0.1872853, avg_kl_loss: 0.6101600
# 295. avg_loss: 0.1880417, avg_rec_loss: 0.1880417, avg_kl_loss: 0.6100741
# 296. avg_loss: 0.1877198, avg_rec_loss: 0.1877198, avg_kl_loss: 0.6104950
# 297. avg_loss: 0.1877109, avg_rec_loss: 0.1877109, avg_kl_loss: 0.6107763
# 298. avg_loss: 0.1880276, avg_rec_loss: 0.1880276, avg_kl_loss: 0.6106820
# 299. avg_loss: 0.1878349, avg_rec_loss: 0.1878349, avg_kl_loss: 0.6108608
# 300. avg_loss: 0.1877096, avg_rec_loss: 0.1877096, avg_kl_loss: 0.6111222
# 301. avg_loss: 0.1866586, avg_rec_loss: 0.1866586, avg_kl_loss: 0.6112181
# 302. avg_loss: 0.1874152, avg_rec_loss: 0.1874152, avg_kl_loss: 0.6115355
# 303. avg_loss: 0.1872808, avg_rec_loss: 0.1872808, avg_kl_loss: 0.6113957
# 304. avg_loss: 0.1867605, avg_rec_loss: 0.1867605, avg_kl_loss: 0.6116551
# 305. avg_loss: 0.1874359, avg_rec_loss: 0.1874359, avg_kl_loss: 0.6119883
# 306. avg_loss: 0.1867406, avg_rec_loss: 0.1867406, avg_kl_loss: 0.6123631
# 307. avg_loss: 0.1873182, avg_rec_loss: 0.1873182, avg_kl_loss: 0.6123078
# 308. avg_loss: 0.1868922, avg_rec_loss: 0.1868922, avg_kl_loss: 0.6125721
# 309. avg_loss: 0.1873316, avg_rec_loss: 0.1873316, avg_kl_loss: 0.6128266
# 310. avg_loss: 0.1872608, avg_rec_loss: 0.1872608, avg_kl_loss: 0.6128157
# 311. avg_loss: 0.1864086, avg_rec_loss: 0.1864086, avg_kl_loss: 0.6129845
# 312. avg_loss: 0.1864859, avg_rec_loss: 0.1864859, avg_kl_loss: 0.6133200
# 313. avg_loss: 0.1866454, avg_rec_loss: 0.1866454, avg_kl_loss: 0.6133710
# 314. avg_loss: 0.1863648, avg_rec_loss: 0.1863648, avg_kl_loss: 0.6135537
# 315. avg_loss: 0.1865144, avg_rec_loss: 0.1865144, avg_kl_loss: 0.6135981
# 316. avg_loss: 0.1862578, avg_rec_loss: 0.1862578, avg_kl_loss: 0.6136509
# 317. avg_loss: 0.1866671, avg_rec_loss: 0.1866671, avg_kl_loss: 0.6142122
# 318. avg_loss: 0.1864776, avg_rec_loss: 0.1864776, avg_kl_loss: 0.6141593
# 319. avg_loss: 0.1860951, avg_rec_loss: 0.1860951, avg_kl_loss: 0.6143123
# 320. avg_loss: 0.1860641, avg_rec_loss: 0.1860641, avg_kl_loss: 0.6147523
# 321. avg_loss: 0.1855038, avg_rec_loss: 0.1855038, avg_kl_loss: 0.6148860
# 322. avg_loss: 0.1863893, avg_rec_loss: 0.1863893, avg_kl_loss: 0.6147272
# 323. avg_loss: 0.1852146, avg_rec_loss: 0.1852146, avg_kl_loss: 0.6151808
# 324. avg_loss: 0.1858177, avg_rec_loss: 0.1858177, avg_kl_loss: 0.6155286
# 325. avg_loss: 0.1857554, avg_rec_loss: 0.1857554, avg_kl_loss: 0.6153329
# 326. avg_loss: 0.1855909, avg_rec_loss: 0.1855909, avg_kl_loss: 0.6154068
# 327. avg_loss: 0.1844772, avg_rec_loss: 0.1844772, avg_kl_loss: 0.6154485
# 328. avg_loss: 0.1848731, avg_rec_loss: 0.1848731, avg_kl_loss: 0.6156409
# 329. avg_loss: 0.1856694, avg_rec_loss: 0.1856694, avg_kl_loss: 0.6157328
# 330. avg_loss: 0.1851420, avg_rec_loss: 0.1851420, avg_kl_loss: 0.6160279
# 331. avg_loss: 0.1843438, avg_rec_loss: 0.1843438, avg_kl_loss: 0.6161393
# 332. avg_loss: 0.1846646, avg_rec_loss: 0.1846646, avg_kl_loss: 0.6164228
# 333. avg_loss: 0.1840905, avg_rec_loss: 0.1840905, avg_kl_loss: 0.6166497
# 334. avg_loss: 0.1846007, avg_rec_loss: 0.1846007, avg_kl_loss: 0.6165516
# 335. avg_loss: 0.1843003, avg_rec_loss: 0.1843003, avg_kl_loss: 0.6166467
# 336. avg_loss: 0.1842754, avg_rec_loss: 0.1842754, avg_kl_loss: 0.6168486
# 337. avg_loss: 0.1841375, avg_rec_loss: 0.1841375, avg_kl_loss: 0.6169522
# 338. avg_loss: 0.1850574, avg_rec_loss: 0.1850574, avg_kl_loss: 0.6171558
# 339. avg_loss: 0.1837771, avg_rec_loss: 0.1837771, avg_kl_loss: 0.6172975
# 340. avg_loss: 0.1843627, avg_rec_loss: 0.1843627, avg_kl_loss: 0.6175378
# 341. avg_loss: 0.1835341, avg_rec_loss: 0.1835341, avg_kl_loss: 0.6176210
# 342. avg_loss: 0.1841363, avg_rec_loss: 0.1841363, avg_kl_loss: 0.6175037
# 343. avg_loss: 0.1841021, avg_rec_loss: 0.1841021, avg_kl_loss: 0.6177738
# 344. avg_loss: 0.1841138, avg_rec_loss: 0.1841138, avg_kl_loss: 0.6178579
# 345. avg_loss: 0.1835587, avg_rec_loss: 0.1835587, avg_kl_loss: 0.6180230
# 346. avg_loss: 0.1844254, avg_rec_loss: 0.1844254, avg_kl_loss: 0.6182084
# 347. avg_loss: 0.1843988, avg_rec_loss: 0.1843988, avg_kl_loss: 0.6183254
# 348. avg_loss: 0.1836163, avg_rec_loss: 0.1836163, avg_kl_loss: 0.6187273
# 349. avg_loss: 0.1843255, avg_rec_loss: 0.1843255, avg_kl_loss: 0.6185690
# 350. avg_loss: 0.1845680, avg_rec_loss: 0.1845680, avg_kl_loss: 0.6185421
# 351. avg_loss: 0.1834598, avg_rec_loss: 0.1834598, avg_kl_loss: 0.6190031
# 352. avg_loss: 0.1833348, avg_rec_loss: 0.1833348, avg_kl_loss: 0.6190873
# 353. avg_loss: 0.1840714, avg_rec_loss: 0.1840714, avg_kl_loss: 0.6192795
# 354. avg_loss: 0.1836451, avg_rec_loss: 0.1836451, avg_kl_loss: 0.6192760
# 355. avg_loss: 0.1822334, avg_rec_loss: 0.1822334, avg_kl_loss: 0.6196178
# 356. avg_loss: 0.1831929, avg_rec_loss: 0.1831929, avg_kl_loss: 0.6198207
# 357. avg_loss: 0.1830062, avg_rec_loss: 0.1830062, avg_kl_loss: 0.6198612
# 358. avg_loss: 0.1836803, avg_rec_loss: 0.1836803, avg_kl_loss: 0.6199591
# 359. avg_loss: 0.1827829, avg_rec_loss: 0.1827829, avg_kl_loss: 0.6200086
# 360. avg_loss: 0.1824394, avg_rec_loss: 0.1824394, avg_kl_loss: 0.6203445
# 361. avg_loss: 0.1831629, avg_rec_loss: 0.1831629, avg_kl_loss: 0.6203558
# 362. avg_loss: 0.1829750, avg_rec_loss: 0.1829750, avg_kl_loss: 0.6205112
# 363. avg_loss: 0.1832608, avg_rec_loss: 0.1832608, avg_kl_loss: 0.6204860
# 364. avg_loss: 0.1828433, avg_rec_loss: 0.1828433, avg_kl_loss: 0.6208353
# 365. avg_loss: 0.1830698, avg_rec_loss: 0.1830698, avg_kl_loss: 0.6209107
# 366. avg_loss: 0.1822314, avg_rec_loss: 0.1822314, avg_kl_loss: 0.6211710
# 367. avg_loss: 0.1826382, avg_rec_loss: 0.1826382, avg_kl_loss: 0.6211769
# 368. avg_loss: 0.1823275, avg_rec_loss: 0.1823275, avg_kl_loss: 0.6213945
# 369. avg_loss: 0.1825095, avg_rec_loss: 0.1825095, avg_kl_loss: 0.6214398
# 370. avg_loss: 0.1824673, avg_rec_loss: 0.1824673, avg_kl_loss: 0.6220655
# 371. avg_loss: 0.1825607, avg_rec_loss: 0.1825607, avg_kl_loss: 0.6220482
# 372. avg_loss: 0.1821040, avg_rec_loss: 0.1821040, avg_kl_loss: 0.6219549
# 373. avg_loss: 0.1825445, avg_rec_loss: 0.1825445, avg_kl_loss: 0.6221527
# 374. avg_loss: 0.1826966, avg_rec_loss: 0.1826966, avg_kl_loss: 0.6221507
# 375. avg_loss: 0.1817772, avg_rec_loss: 0.1817772, avg_kl_loss: 0.6221841
# 376. avg_loss: 0.1819992, avg_rec_loss: 0.1819992, avg_kl_loss: 0.6226868
# 377. avg_loss: 0.1817959, avg_rec_loss: 0.1817959, avg_kl_loss: 0.6228169
# 378. avg_loss: 0.1815853, avg_rec_loss: 0.1815853, avg_kl_loss: 0.6229865
# 379. avg_loss: 0.1813719, avg_rec_loss: 0.1813719, avg_kl_loss: 0.6226603
# 380. avg_loss: 0.1823303, avg_rec_loss: 0.1823303, avg_kl_loss: 0.6230091
# 381. avg_loss: 0.1816337, avg_rec_loss: 0.1816337, avg_kl_loss: 0.6230900
# 382. avg_loss: 0.1822320, avg_rec_loss: 0.1822320, avg_kl_loss: 0.6235729
# 383. avg_loss: 0.1816396, avg_rec_loss: 0.1816396, avg_kl_loss: 0.6235639
# 384. avg_loss: 0.1812944, avg_rec_loss: 0.1812944, avg_kl_loss: 0.6237587
# 385. avg_loss: 0.1811581, avg_rec_loss: 0.1811581, avg_kl_loss: 0.6236908
# 386. avg_loss: 0.1811712, avg_rec_loss: 0.1811712, avg_kl_loss: 0.6239815
# 387. avg_loss: 0.1808019, avg_rec_loss: 0.1808019, avg_kl_loss: 0.6243312
# 388. avg_loss: 0.1813852, avg_rec_loss: 0.1813852, avg_kl_loss: 0.6240608
# 389. avg_loss: 0.1811019, avg_rec_loss: 0.1811019, avg_kl_loss: 0.6242152
# 390. avg_loss: 0.1812357, avg_rec_loss: 0.1812357, avg_kl_loss: 0.6242908
# 391. avg_loss: 0.1809469, avg_rec_loss: 0.1809469, avg_kl_loss: 0.6246735
# 392. avg_loss: 0.1812171, avg_rec_loss: 0.1812171, avg_kl_loss: 0.6247093
# 393. avg_loss: 0.1804610, avg_rec_loss: 0.1804610, avg_kl_loss: 0.6249338
# 394. avg_loss: 0.1803473, avg_rec_loss: 0.1803473, avg_kl_loss: 0.6250500
# 395. avg_loss: 0.1811514, avg_rec_loss: 0.1811514, avg_kl_loss: 0.6251596
# 396. avg_loss: 0.1810079, avg_rec_loss: 0.1810079, avg_kl_loss: 0.6253322
# 397. avg_loss: 0.1811033, avg_rec_loss: 0.1811033, avg_kl_loss: 0.6252550
# 398. avg_loss: 0.1809755, avg_rec_loss: 0.1809755, avg_kl_loss: 0.6253334
# 399. avg_loss: 0.1807737, avg_rec_loss: 0.1807737, avg_kl_loss: 0.6255055
# 400. avg_loss: 0.1803615, avg_rec_loss: 0.1803615, avg_kl_loss: 0.6256784
# 401. avg_loss: 0.1806468, avg_rec_loss: 0.1806468, avg_kl_loss: 0.6257129
# 402. avg_loss: 0.1808364, avg_rec_loss: 0.1808364, avg_kl_loss: 0.6259007
# 403. avg_loss: 0.1801091, avg_rec_loss: 0.1801091, avg_kl_loss: 0.6265924
# 404. avg_loss: 0.1802808, avg_rec_loss: 0.1802808, avg_kl_loss: 0.6263564
# 405. avg_loss: 0.1805060, avg_rec_loss: 0.1805060, avg_kl_loss: 0.6264788
# 406. avg_loss: 0.1800666, avg_rec_loss: 0.1800666, avg_kl_loss: 0.6264747
# 407. avg_loss: 0.1798353, avg_rec_loss: 0.1798353, avg_kl_loss: 0.6266235
# 408. avg_loss: 0.1794534, avg_rec_loss: 0.1794534, avg_kl_loss: 0.6265959
# 409. avg_loss: 0.1796305, avg_rec_loss: 0.1796305, avg_kl_loss: 0.6268288
# 410. avg_loss: 0.1797877, avg_rec_loss: 0.1797877, avg_kl_loss: 0.6270384
# 411. avg_loss: 0.1802741, avg_rec_loss: 0.1802741, avg_kl_loss: 0.6269631
# 412. avg_loss: 0.1797336, avg_rec_loss: 0.1797336, avg_kl_loss: 0.6271857
# 413. avg_loss: 0.1796628, avg_rec_loss: 0.1796628, avg_kl_loss: 0.6270967
# 414. avg_loss: 0.1797660, avg_rec_loss: 0.1797660, avg_kl_loss: 0.6271425
# 415. avg_loss: 0.1790949, avg_rec_loss: 0.1790949, avg_kl_loss: 0.6274666
# 416. avg_loss: 0.1799087, avg_rec_loss: 0.1799087, avg_kl_loss: 0.6277746
# 417. avg_loss: 0.1798134, avg_rec_loss: 0.1798134, avg_kl_loss: 0.6277354
# 418. avg_loss: 0.1808973, avg_rec_loss: 0.1808973, avg_kl_loss: 0.6276963
# 419. avg_loss: 0.1798146, avg_rec_loss: 0.1798146, avg_kl_loss: 0.6278524
# 420. avg_loss: 0.1801784, avg_rec_loss: 0.1801784, avg_kl_loss: 0.6277314
# 421. avg_loss: 0.1792309, avg_rec_loss: 0.1792309, avg_kl_loss: 0.6284378
# 422. avg_loss: 0.1790939, avg_rec_loss: 0.1790939, avg_kl_loss: 0.6282486
# 423. avg_loss: 0.1796804, avg_rec_loss: 0.1796804, avg_kl_loss: 0.6286248
# 424. avg_loss: 0.1796263, avg_rec_loss: 0.1796263, avg_kl_loss: 0.6286961
# 425. avg_loss: 0.1800883, avg_rec_loss: 0.1800883, avg_kl_loss: 0.6286672
# 426. avg_loss: 0.1797115, avg_rec_loss: 0.1797115, avg_kl_loss: 0.6289378
# 427. avg_loss: 0.1799119, avg_rec_loss: 0.1799119, avg_kl_loss: 0.6292122
# 428. avg_loss: 0.1802153, avg_rec_loss: 0.1802153, avg_kl_loss: 0.6289203
# 429. avg_loss: 0.1793911, avg_rec_loss: 0.1793911, avg_kl_loss: 0.6294938
# 430. avg_loss: 0.1796979, avg_rec_loss: 0.1796979, avg_kl_loss: 0.6295036
# 431. avg_loss: 0.1794448, avg_rec_loss: 0.1794448, avg_kl_loss: 0.6296018
# 432. avg_loss: 0.1801563, avg_rec_loss: 0.1801563, avg_kl_loss: 0.6294127
# 433. avg_loss: 0.1791591, avg_rec_loss: 0.1791591, avg_kl_loss: 0.6297123
# 434. avg_loss: 0.1797579, avg_rec_loss: 0.1797579, avg_kl_loss: 0.6296741
# 435. avg_loss: 0.1794308, avg_rec_loss: 0.1794308, avg_kl_loss: 0.6298813
# 436. avg_loss: 0.1792952, avg_rec_loss: 0.1792952, avg_kl_loss: 0.6301100
# 437. avg_loss: 0.1798344, avg_rec_loss: 0.1798344, avg_kl_loss: 0.6300810
# 438. avg_loss: 0.1799984, avg_rec_loss: 0.1799984, avg_kl_loss: 0.6301384
# 439. avg_loss: 0.1798572, avg_rec_loss: 0.1798572, avg_kl_loss: 0.6302956
# 440. avg_loss: 0.1801218, avg_rec_loss: 0.1801218, avg_kl_loss: 0.6306011
# 441. avg_loss: 0.1793153, avg_rec_loss: 0.1793153, avg_kl_loss: 0.6306450
# 442. avg_loss: 0.1790518, avg_rec_loss: 0.1790518, avg_kl_loss: 0.6311554
# 443. avg_loss: 0.1794880, avg_rec_loss: 0.1794880, avg_kl_loss: 0.6308503
# 444. avg_loss: 0.1795177, avg_rec_loss: 0.1795177, avg_kl_loss: 0.6312483
# 445. avg_loss: 0.1801595, avg_rec_loss: 0.1801595, avg_kl_loss: 0.6312300
# 446. avg_loss: 0.1787763, avg_rec_loss: 0.1787763, avg_kl_loss: 0.6316782
# 447. avg_loss: 0.1796766, avg_rec_loss: 0.1796766, avg_kl_loss: 0.6316109
# 448. avg_loss: 0.1795034, avg_rec_loss: 0.1795034, avg_kl_loss: 0.6319788
# 449. avg_loss: 0.1793001, avg_rec_loss: 0.1793001, avg_kl_loss: 0.6319035
# 450. avg_loss: 0.1795268, avg_rec_loss: 0.1795268, avg_kl_loss: 0.6317717
# 451. avg_loss: 0.1798459, avg_rec_loss: 0.1798459, avg_kl_loss: 0.6320899
# 452. avg_loss: 0.1796960, avg_rec_loss: 0.1796960, avg_kl_loss: 0.6322667
# 453. avg_loss: 0.1791184, avg_rec_loss: 0.1791184, avg_kl_loss: 0.6324235
# 454. avg_loss: 0.1797657, avg_rec_loss: 0.1797657, avg_kl_loss: 0.6323335
# 455. avg_loss: 0.1795894, avg_rec_loss: 0.1795894, avg_kl_loss: 0.6324069
# 456. avg_loss: 0.1783935, avg_rec_loss: 0.1783935, avg_kl_loss: 0.6329034
# 457. avg_loss: 0.1793790, avg_rec_loss: 0.1793790, avg_kl_loss: 0.6326915
# 458. avg_loss: 0.1793175, avg_rec_loss: 0.1793175, avg_kl_loss: 0.6330626
# 459. avg_loss: 0.1797466, avg_rec_loss: 0.1797466, avg_kl_loss: 0.6329514
# 460. avg_loss: 0.1791945, avg_rec_loss: 0.1791945, avg_kl_loss: 0.6331251
# 461. avg_loss: 0.1795532, avg_rec_loss: 0.1795532, avg_kl_loss: 0.6333991
# 462. avg_loss: 0.1785972, avg_rec_loss: 0.1785972, avg_kl_loss: 0.6336294
# 463. avg_loss: 0.1790475, avg_rec_loss: 0.1790475, avg_kl_loss: 0.6336710
# 464. avg_loss: 0.1791226, avg_rec_loss: 0.1791226, avg_kl_loss: 0.6337444
# 465. avg_loss: 0.1788011, avg_rec_loss: 0.1788011, avg_kl_loss: 0.6340356
# 466. avg_loss: 0.1797528, avg_rec_loss: 0.1797528, avg_kl_loss: 0.6336811
# 467. avg_loss: 0.1792092, avg_rec_loss: 0.1792092, avg_kl_loss: 0.6342150
# 468. avg_loss: 0.1790873, avg_rec_loss: 0.1790873, avg_kl_loss: 0.6341684
# 469. avg_loss: 0.1792617, avg_rec_loss: 0.1792617, avg_kl_loss: 0.6341893
# 470. avg_loss: 0.1784180, avg_rec_loss: 0.1784180, avg_kl_loss: 0.6343995
# 471. avg_loss: 0.1784899, avg_rec_loss: 0.1784899, avg_kl_loss: 0.6346155
# 472. avg_loss: 0.1782098, avg_rec_loss: 0.1782098, avg_kl_loss: 0.6347480
# 473. avg_loss: 0.1785602, avg_rec_loss: 0.1785602, avg_kl_loss: 0.6346889
# 474. avg_loss: 0.1782112, avg_rec_loss: 0.1782112, avg_kl_loss: 0.6348868
# 475. avg_loss: 0.1779335, avg_rec_loss: 0.1779335, avg_kl_loss: 0.6351644
# 476. avg_loss: 0.1779825, avg_rec_loss: 0.1779825, avg_kl_loss: 0.6350228
# 477. avg_loss: 0.1782978, avg_rec_loss: 0.1782978, avg_kl_loss: 0.6351043
# 478. avg_loss: 0.1778752, avg_rec_loss: 0.1778752, avg_kl_loss: 0.6354904
# 479. avg_loss: 0.1781744, avg_rec_loss: 0.1781744, avg_kl_loss: 0.6356084
# 480. avg_loss: 0.1784312, avg_rec_loss: 0.1784312, avg_kl_loss: 0.6355244
# 481. avg_loss: 0.1776139, avg_rec_loss: 0.1776139, avg_kl_loss: 0.6357757
# 482. avg_loss: 0.1778781, avg_rec_loss: 0.1778781, avg_kl_loss: 0.6357971
# 483. avg_loss: 0.1771724, avg_rec_loss: 0.1771724, avg_kl_loss: 0.6361127
# 484. avg_loss: 0.1776724, avg_rec_loss: 0.1776724, avg_kl_loss: 0.6358662
# 485. avg_loss: 0.1772051, avg_rec_loss: 0.1772051, avg_kl_loss: 0.6360257
# 486. avg_loss: 0.1771864, avg_rec_loss: 0.1771864, avg_kl_loss: 0.6360662
# 487. avg_loss: 0.1779757, avg_rec_loss: 0.1779757, avg_kl_loss: 0.6360137
# 488. avg_loss: 0.1784738, avg_rec_loss: 0.1784738, avg_kl_loss: 0.6363005
# 489. avg_loss: 0.1778007, avg_rec_loss: 0.1778007, avg_kl_loss: 0.6364550
# 490. avg_loss: 0.1778793, avg_rec_loss: 0.1778793, avg_kl_loss: 0.6366780
# 491. avg_loss: 0.1765665, avg_rec_loss: 0.1765665, avg_kl_loss: 0.6367002
# 492. avg_loss: 0.1776559, avg_rec_loss: 0.1776559, avg_kl_loss: 0.6366903
# 493. avg_loss: 0.1767920, avg_rec_loss: 0.1767920, avg_kl_loss: 0.6372364
# 494. avg_loss: 0.1773942, avg_rec_loss: 0.1773942, avg_kl_loss: 0.6369609
# 495. avg_loss: 0.1770904, avg_rec_loss: 0.1770904, avg_kl_loss: 0.6371320
# 496. avg_loss: 0.1780167, avg_rec_loss: 0.1780167, avg_kl_loss: 0.6371324
# 497. avg_loss: 0.1775602, avg_rec_loss: 0.1775602, avg_kl_loss: 0.6372250
# 498. avg_loss: 0.1770099, avg_rec_loss: 0.1770099, avg_kl_loss: 0.6374340
# 499. avg_loss: 0.1767178, avg_rec_loss: 0.1767178, avg_kl_loss: 0.6375085
# 500. avg_loss: 0.1773083, avg_rec_loss: 0.1773083, avg_kl_loss: 0.6376050
# 501. avg_loss: 0.1774395, avg_rec_loss: 0.1774395, avg_kl_loss: 0.6377867
# 502. avg_loss: 0.1777448, avg_rec_loss: 0.1777448, avg_kl_loss: 0.6377955
# 503. avg_loss: 0.1771423, avg_rec_loss: 0.1771423, avg_kl_loss: 0.6377373
# 504. avg_loss: 0.1771006, avg_rec_loss: 0.1771006, avg_kl_loss: 0.6382063
# 505. avg_loss: 0.1775140, avg_rec_loss: 0.1775140, avg_kl_loss: 0.6381350
# 506. avg_loss: 0.1774000, avg_rec_loss: 0.1774000, avg_kl_loss: 0.6383281
# 507. avg_loss: 0.1772196, avg_rec_loss: 0.1772196, avg_kl_loss: 0.6383866
# 508. avg_loss: 0.1781004, avg_rec_loss: 0.1781004, avg_kl_loss: 0.6380785
# 509. avg_loss: 0.1768127, avg_rec_loss: 0.1768127, avg_kl_loss: 0.6385829
# 510. avg_loss: 0.1771708, avg_rec_loss: 0.1771708, avg_kl_loss: 0.6386390
# 511. avg_loss: 0.1771254, avg_rec_loss: 0.1771254, avg_kl_loss: 0.6388118
# 512. avg_loss: 0.1770877, avg_rec_loss: 0.1770877, avg_kl_loss: 0.6389562
# 513. avg_loss: 0.1770165, avg_rec_loss: 0.1770165, avg_kl_loss: 0.6390575
# 514. avg_loss: 0.1774175, avg_rec_loss: 0.1774175, avg_kl_loss: 0.6390779
# 515. avg_loss: 0.1769797, avg_rec_loss: 0.1769797, avg_kl_loss: 0.6389620
# 516. avg_loss: 0.1773604, avg_rec_loss: 0.1773604, avg_kl_loss: 0.6390862
# 517. avg_loss: 0.1764801, avg_rec_loss: 0.1764801, avg_kl_loss: 0.6394711
# 518. avg_loss: 0.1765113, avg_rec_loss: 0.1765113, avg_kl_loss: 0.6394214
# 519. avg_loss: 0.1765836, avg_rec_loss: 0.1765836, avg_kl_loss: 0.6398007
# 520. avg_loss: 0.1775991, avg_rec_loss: 0.1775991, avg_kl_loss: 0.6394609
# 521. avg_loss: 0.1770212, avg_rec_loss: 0.1770212, avg_kl_loss: 0.6397481
# 522. avg_loss: 0.1764519, avg_rec_loss: 0.1764519, avg_kl_loss: 0.6400153
# 523. avg_loss: 0.1763904, avg_rec_loss: 0.1763904, avg_kl_loss: 0.6400298
# 524. avg_loss: 0.1767843, avg_rec_loss: 0.1767843, avg_kl_loss: 0.6403628
# 525. avg_loss: 0.1764993, avg_rec_loss: 0.1764993, avg_kl_loss: 0.6403430
# 526. avg_loss: 0.1766489, avg_rec_loss: 0.1766489, avg_kl_loss: 0.6404897
# 527. avg_loss: 0.1757541, avg_rec_loss: 0.1757541, avg_kl_loss: 0.6405701
# 528. avg_loss: 0.1762162, avg_rec_loss: 0.1762162, avg_kl_loss: 0.6403875
# 529. avg_loss: 0.1758292, avg_rec_loss: 0.1758292, avg_kl_loss: 0.6409441
# 530. avg_loss: 0.1755287, avg_rec_loss: 0.1755287, avg_kl_loss: 0.6406862
# 531. avg_loss: 0.1756600, avg_rec_loss: 0.1756600, avg_kl_loss: 0.6409558
# 532. avg_loss: 0.1770185, avg_rec_loss: 0.1770185, avg_kl_loss: 0.6405182
# 533. avg_loss: 0.1760642, avg_rec_loss: 0.1760642, avg_kl_loss: 0.6410261
# 534. avg_loss: 0.1756935, avg_rec_loss: 0.1756935, avg_kl_loss: 0.6410757
# 535. avg_loss: 0.1759198, avg_rec_loss: 0.1759198, avg_kl_loss: 0.6411588
# 536. avg_loss: 0.1749415, avg_rec_loss: 0.1749415, avg_kl_loss: 0.6415390
# 537. avg_loss: 0.1754181, avg_rec_loss: 0.1754181, avg_kl_loss: 0.6415203
# 538. avg_loss: 0.1761231, avg_rec_loss: 0.1761231, avg_kl_loss: 0.6414654
# 539. avg_loss: 0.1754076, avg_rec_loss: 0.1754076, avg_kl_loss: 0.6414250
# 540. avg_loss: 0.1758074, avg_rec_loss: 0.1758074, avg_kl_loss: 0.6415599
# 541. avg_loss: 0.1749344, avg_rec_loss: 0.1749344, avg_kl_loss: 0.6419404
# 542. avg_loss: 0.1757494, avg_rec_loss: 0.1757494, avg_kl_loss: 0.6416379
# 543. avg_loss: 0.1746381, avg_rec_loss: 0.1746381, avg_kl_loss: 0.6416461
# 544. avg_loss: 0.1755886, avg_rec_loss: 0.1755886, avg_kl_loss: 0.6420506
# 545. avg_loss: 0.1747028, avg_rec_loss: 0.1747028, avg_kl_loss: 0.6423026
# 546. avg_loss: 0.1749521, avg_rec_loss: 0.1749521, avg_kl_loss: 0.6424351
# 547. avg_loss: 0.1749065, avg_rec_loss: 0.1749065, avg_kl_loss: 0.6422010
# 548. avg_loss: 0.1750059, avg_rec_loss: 0.1750059, avg_kl_loss: 0.6425036
# 549. avg_loss: 0.1745947, avg_rec_loss: 0.1745947, avg_kl_loss: 0.6424999
# 550. avg_loss: 0.1747527, avg_rec_loss: 0.1747527, avg_kl_loss: 0.6424186
# 551. avg_loss: 0.1744974, avg_rec_loss: 0.1744974, avg_kl_loss: 0.6429553
# 552. avg_loss: 0.1744474, avg_rec_loss: 0.1744474, avg_kl_loss: 0.6427172
# 553. avg_loss: 0.1743942, avg_rec_loss: 0.1743942, avg_kl_loss: 0.6427221
# 554. avg_loss: 0.1747245, avg_rec_loss: 0.1747245, avg_kl_loss: 0.6427317
# 555. avg_loss: 0.1743254, avg_rec_loss: 0.1743254, avg_kl_loss: 0.6430311
# 556. avg_loss: 0.1754456, avg_rec_loss: 0.1754456, avg_kl_loss: 0.6429695
# 557. avg_loss: 0.1740904, avg_rec_loss: 0.1740904, avg_kl_loss: 0.6431111
# 558. avg_loss: 0.1745239, avg_rec_loss: 0.1745239, avg_kl_loss: 0.6432821
# 559. avg_loss: 0.1746004, avg_rec_loss: 0.1746004, avg_kl_loss: 0.6430038
# 560. avg_loss: 0.1744698, avg_rec_loss: 0.1744698, avg_kl_loss: 0.6432099
# 561. avg_loss: 0.1744391, avg_rec_loss: 0.1744391, avg_kl_loss: 0.6433676
# 562. avg_loss: 0.1747837, avg_rec_loss: 0.1747837, avg_kl_loss: 0.6435247
# 563. avg_loss: 0.1744543, avg_rec_loss: 0.1744543, avg_kl_loss: 0.6435171
# 564. avg_loss: 0.1745112, avg_rec_loss: 0.1745112, avg_kl_loss: 0.6435881
# 565. avg_loss: 0.1740928, avg_rec_loss: 0.1740928, avg_kl_loss: 0.6439515
# 566. avg_loss: 0.1740437, avg_rec_loss: 0.1740437, avg_kl_loss: 0.6439240
# 567. avg_loss: 0.1740437, avg_rec_loss: 0.1740437, avg_kl_loss: 0.6440474
# 568. avg_loss: 0.1736220, avg_rec_loss: 0.1736220, avg_kl_loss: 0.6441835
# 569. avg_loss: 0.1739259, avg_rec_loss: 0.1739259, avg_kl_loss: 0.6443380
# 570. avg_loss: 0.1743387, avg_rec_loss: 0.1743387, avg_kl_loss: 0.6441281
# 571. avg_loss: 0.1744501, avg_rec_loss: 0.1744501, avg_kl_loss: 0.6442056
# 572. avg_loss: 0.1739680, avg_rec_loss: 0.1739680, avg_kl_loss: 0.6446174
# 573. avg_loss: 0.1735283, avg_rec_loss: 0.1735283, avg_kl_loss: 0.6447956
# 574. avg_loss: 0.1741552, avg_rec_loss: 0.1741552, avg_kl_loss: 0.6448071
# 575. avg_loss: 0.1741734, avg_rec_loss: 0.1741734, avg_kl_loss: 0.6446872
# 576. avg_loss: 0.1735653, avg_rec_loss: 0.1735653, avg_kl_loss: 0.6450761
# 577. avg_loss: 0.1739858, avg_rec_loss: 0.1739858, avg_kl_loss: 0.6444291
# 578. avg_loss: 0.1746464, avg_rec_loss: 0.1746464, avg_kl_loss: 0.6448543
# 579. avg_loss: 0.1729323, avg_rec_loss: 0.1729323, avg_kl_loss: 0.6451594
# 580. avg_loss: 0.1732577, avg_rec_loss: 0.1732577, avg_kl_loss: 0.6449673
# 581. avg_loss: 0.1731247, avg_rec_loss: 0.1731247, avg_kl_loss: 0.6452860
# 582. avg_loss: 0.1736314, avg_rec_loss: 0.1736314, avg_kl_loss: 0.6452759
# 583. avg_loss: 0.1733779, avg_rec_loss: 0.1733779, avg_kl_loss: 0.6452858
# 584. avg_loss: 0.1730195, avg_rec_loss: 0.1730195, avg_kl_loss: 0.6453718
# 585. avg_loss: 0.1731770, avg_rec_loss: 0.1731770, avg_kl_loss: 0.6454402
# 586. avg_loss: 0.1731397, avg_rec_loss: 0.1731397, avg_kl_loss: 0.6454537
# 587. avg_loss: 0.1730426, avg_rec_loss: 0.1730426, avg_kl_loss: 0.6455281
# 588. avg_loss: 0.1731971, avg_rec_loss: 0.1731971, avg_kl_loss: 0.6454612
# 589. avg_loss: 0.1722711, avg_rec_loss: 0.1722711, avg_kl_loss: 0.6459798
# 590. avg_loss: 0.1728390, avg_rec_loss: 0.1728390, avg_kl_loss: 0.6457087
# 591. avg_loss: 0.1736222, avg_rec_loss: 0.1736222, avg_kl_loss: 0.6455562
# 592. avg_loss: 0.1730931, avg_rec_loss: 0.1730931, avg_kl_loss: 0.6457293
# 593. avg_loss: 0.1731842, avg_rec_loss: 0.1731842, avg_kl_loss: 0.6459150
# 594. avg_loss: 0.1730082, avg_rec_loss: 0.1730082, avg_kl_loss: 0.6459888
# 595. avg_loss: 0.1733616, avg_rec_loss: 0.1733616, avg_kl_loss: 0.6460537
# 596. avg_loss: 0.1732286, avg_rec_loss: 0.1732286, avg_kl_loss: 0.6461578
# 597. avg_loss: 0.1727438, avg_rec_loss: 0.1727438, avg_kl_loss: 0.6463816
# 598. avg_loss: 0.1724909, avg_rec_loss: 0.1724909, avg_kl_loss: 0.6465401
# 599. avg_loss: 0.1722153, avg_rec_loss: 0.1722153, avg_kl_loss: 0.6466302
# 600. avg_loss: 0.1726716, avg_rec_loss: 0.1726716, avg_kl_loss: 0.6461711
# 601. avg_loss: 0.1728830, avg_rec_loss: 0.1728830, avg_kl_loss: 0.6465685
# 602. avg_loss: 0.1723726, avg_rec_loss: 0.1723726, avg_kl_loss: 0.6467961
# 603. avg_loss: 0.1721759, avg_rec_loss: 0.1721759, avg_kl_loss: 0.6469227
# 604. avg_loss: 0.1721742, avg_rec_loss: 0.1721742, avg_kl_loss: 0.6468456
# 605. avg_loss: 0.1728354, avg_rec_loss: 0.1728354, avg_kl_loss: 0.6467742
# 606. avg_loss: 0.1721116, avg_rec_loss: 0.1721116, avg_kl_loss: 0.6470326
# 607. avg_loss: 0.1730045, avg_rec_loss: 0.1730045, avg_kl_loss: 0.6471179
# 608. avg_loss: 0.1732495, avg_rec_loss: 0.1732495, avg_kl_loss: 0.6470755
# 609. avg_loss: 0.1724303, avg_rec_loss: 0.1724303, avg_kl_loss: 0.6469592
# 610. avg_loss: 0.1720237, avg_rec_loss: 0.1720237, avg_kl_loss: 0.6471291
# 611. avg_loss: 0.1723306, avg_rec_loss: 0.1723306, avg_kl_loss: 0.6470576
# 612. avg_loss: 0.1728082, avg_rec_loss: 0.1728082, avg_kl_loss: 0.6472442
# 613. avg_loss: 0.1724152, avg_rec_loss: 0.1724152, avg_kl_loss: 0.6473356
# 614. avg_loss: 0.1727609, avg_rec_loss: 0.1727609, avg_kl_loss: 0.6473326
# 615. avg_loss: 0.1728927, avg_rec_loss: 0.1728927, avg_kl_loss: 0.6474945
# 616. avg_loss: 0.1730401, avg_rec_loss: 0.1730401, avg_kl_loss: 0.6478094
# 617. avg_loss: 0.1724772, avg_rec_loss: 0.1724772, avg_kl_loss: 0.6479529
# 618. avg_loss: 0.1725878, avg_rec_loss: 0.1725878, avg_kl_loss: 0.6478582
# 619. avg_loss: 0.1716280, avg_rec_loss: 0.1716280, avg_kl_loss: 0.6478159
# 620. avg_loss: 0.1726291, avg_rec_loss: 0.1726291, avg_kl_loss: 0.6479231
# 621. avg_loss: 0.1721336, avg_rec_loss: 0.1721336, avg_kl_loss: 0.6477187
# 622. avg_loss: 0.1726030, avg_rec_loss: 0.1726030, avg_kl_loss: 0.6483685
# 623. avg_loss: 0.1722972, avg_rec_loss: 0.1722972, avg_kl_loss: 0.6481837
# 624. avg_loss: 0.1719889, avg_rec_loss: 0.1719889, avg_kl_loss: 0.6485789
# 625. avg_loss: 0.1724037, avg_rec_loss: 0.1724037, avg_kl_loss: 0.6482386
# 626. avg_loss: 0.1721584, avg_rec_loss: 0.1721584, avg_kl_loss: 0.6482619
# 627. avg_loss: 0.1728689, avg_rec_loss: 0.1728689, avg_kl_loss: 0.6483955
# 628. avg_loss: 0.1725441, avg_rec_loss: 0.1725441, avg_kl_loss: 0.6485424
# 629. avg_loss: 0.1724635, avg_rec_loss: 0.1724635, avg_kl_loss: 0.6487855
# 630. avg_loss: 0.1712367, avg_rec_loss: 0.1712367, avg_kl_loss: 0.6489119
# 631. avg_loss: 0.1712856, avg_rec_loss: 0.1712856, avg_kl_loss: 0.6488380
# 632. avg_loss: 0.1726220, avg_rec_loss: 0.1726220, avg_kl_loss: 0.6485966
# 633. avg_loss: 0.1719794, avg_rec_loss: 0.1719794, avg_kl_loss: 0.6488200
# 634. avg_loss: 0.1719093, avg_rec_loss: 0.1719093, avg_kl_loss: 0.6488975
# 635. avg_loss: 0.1721358, avg_rec_loss: 0.1721358, avg_kl_loss: 0.6486502
# 636. avg_loss: 0.1714100, avg_rec_loss: 0.1714100, avg_kl_loss: 0.6492211
# 637. avg_loss: 0.1711153, avg_rec_loss: 0.1711153, avg_kl_loss: 0.6491355
# 638. avg_loss: 0.1708063, avg_rec_loss: 0.1708063, avg_kl_loss: 0.6492350
# 639. avg_loss: 0.1713781, avg_rec_loss: 0.1713781, avg_kl_loss: 0.6492052
# 640. avg_loss: 0.1718685, avg_rec_loss: 0.1718685, avg_kl_loss: 0.6493206
# 641. avg_loss: 0.1714187, avg_rec_loss: 0.1714187, avg_kl_loss: 0.6493551
# 642. avg_loss: 0.1714576, avg_rec_loss: 0.1714576, avg_kl_loss: 0.6493385
# 643. avg_loss: 0.1718008, avg_rec_loss: 0.1718008, avg_kl_loss: 0.6494331
# 644. avg_loss: 0.1708873, avg_rec_loss: 0.1708873, avg_kl_loss: 0.6497464
# 645. avg_loss: 0.1716127, avg_rec_loss: 0.1716127, avg_kl_loss: 0.6498013
# 646. avg_loss: 0.1710750, avg_rec_loss: 0.1710750, avg_kl_loss: 0.6496555
# 647. avg_loss: 0.1712677, avg_rec_loss: 0.1712677, avg_kl_loss: 0.6499549
# 648. avg_loss: 0.1712976, avg_rec_loss: 0.1712976, avg_kl_loss: 0.6496291
# ...
# 785. avg_loss: 0.1684010, avg_rec_loss: 0.1684010, avg_kl_loss: 0.6581431
# 786. avg_loss: 0.1681479, avg_rec_loss: 0.1681479, avg_kl_loss: 0.6581867
# 787. avg_loss: 0.1673906, avg_rec_loss: 0.1673906, avg_kl_loss: 0.6580503
# 788. avg_loss: 0.1681702, avg_rec_loss: 0.1681702, avg_kl_loss: 0.6579850
# 789. avg_loss: 0.1675637, avg_rec_loss: 0.1675637, avg_kl_loss: 0.6582107
# 790. avg_loss: 0.1679332, avg_rec_loss: 0.1679332, avg_kl_loss: 0.6585008
# 791. avg_loss: 0.1682768, avg_rec_loss: 0.1682768, avg_kl_loss: 0.6584470
# 792. avg_loss: 0.1673255, avg_rec_loss: 0.1673255, avg_kl_loss: 0.6583566
# 793. avg_loss: 0.1675332, avg_rec_loss: 0.1675332, avg_kl_loss: 0.6584172
# 794. avg_loss: 0.1675948, avg_rec_loss: 0.1675948, avg_kl_loss: 0.6584294
# 795. avg_loss: 0.1676218, avg_rec_loss: 0.1676218, avg_kl_loss: 0.6586702
# 796. avg_loss: 0.1665894, avg_rec_loss: 0.1665894, avg_kl_loss: 0.6585688
# 797. avg_loss: 0.1676090, avg_rec_loss: 0.1676090, avg_kl_loss: 0.6584395
# 798. avg_loss: 0.1669423, avg_rec_loss: 0.1669423, avg_kl_loss: 0.6586686
# 799. avg_loss: 0.1680607, avg_rec_loss: 0.1680607, avg_kl_loss: 0.6584994
# 800. avg_loss: 0.1676450, avg_rec_loss: 0.1676450, avg_kl_loss: 0.6589487
# 801. avg_loss: 0.1677567, avg_rec_loss: 0.1677567, avg_kl_loss: 0.6588548
# 802. avg_loss: 0.1671431, avg_rec_loss: 0.1671431, avg_kl_loss: 0.6588612
# 803. avg_loss: 0.1665883, avg_rec_loss: 0.1665883, avg_kl_loss: 0.6590012
# 804. avg_loss: 0.1666050, avg_rec_loss: 0.1666050, avg_kl_loss: 0.6593176
# 805. avg_loss: 0.1672152, avg_rec_loss: 0.1672152, avg_kl_loss: 0.6590996
# 806. avg_loss: 0.1667383, avg_rec_loss: 0.1667383, avg_kl_loss: 0.6593089
# 807. avg_loss: 0.1672015, avg_rec_loss: 0.1672015, avg_kl_loss: 0.6592239
# 808. avg_loss: 0.1664975, avg_rec_loss: 0.1664975, avg_kl_loss: 0.6594340
# 809. avg_loss: 0.1669783, avg_rec_loss: 0.1669783, avg_kl_loss: 0.6592151
# 810. avg_loss: 0.1672480, avg_rec_loss: 0.1672480, avg_kl_loss: 0.6592782
# 811. avg_loss: 0.1670097, avg_rec_loss: 0.1670097, avg_kl_loss: 0.6591936
# 812. avg_loss: 0.1669541, avg_rec_loss: 0.1669541, avg_kl_loss: 0.6593773
# 813. avg_loss: 0.1666413, avg_rec_loss: 0.1666413, avg_kl_loss: 0.6596053
# 814. avg_loss: 0.1670003, avg_rec_loss: 0.1670003, avg_kl_loss: 0.6597667
# 815. avg_loss: 0.1665517, avg_rec_loss: 0.1665517, avg_kl_loss: 0.6599010
# 816. avg_loss: 0.1663942, avg_rec_loss: 0.1663942, avg_kl_loss: 0.6598198
# 817. avg_loss: 0.1673554, avg_rec_loss: 0.1673554, avg_kl_loss: 0.6594923
# 818. avg_loss: 0.1668480, avg_rec_loss: 0.1668480, avg_kl_loss: 0.6599745
# 819. avg_loss: 0.1667489, avg_rec_loss: 0.1667489, avg_kl_loss: 0.6597416
# 820. avg_loss: 0.1659051, avg_rec_loss: 0.1659051, avg_kl_loss: 0.6596988
# 821. avg_loss: 0.1661668, avg_rec_loss: 0.1661668, avg_kl_loss: 0.6598794
# 822. avg_loss: 0.1659036, avg_rec_loss: 0.1659036, avg_kl_loss: 0.6601660
# 823. avg_loss: 0.1661200, avg_rec_loss: 0.1661200, avg_kl_loss: 0.6603728
# 824. avg_loss: 0.1661708, avg_rec_loss: 0.1661708, avg_kl_loss: 0.6604418
# 825. avg_loss: 0.1664268, avg_rec_loss: 0.1664268, avg_kl_loss: 0.6602692
# 826. avg_loss: 0.1662283, avg_rec_loss: 0.1662283, avg_kl_loss: 0.6601568
# 827. avg_loss: 0.1671738, avg_rec_loss: 0.1671738, avg_kl_loss: 0.6600154
# 828. avg_loss: 0.1663890, avg_rec_loss: 0.1663890, avg_kl_loss: 0.6601911
# 829. avg_loss: 0.1665651, avg_rec_loss: 0.1665651, avg_kl_loss: 0.6603276
# 830. avg_loss: 0.1657429, avg_rec_loss: 0.1657429, avg_kl_loss: 0.6605523
# 831. avg_loss: 0.1662977, avg_rec_loss: 0.1662977, avg_kl_loss: 0.6604871
# 832. avg_loss: 0.1663794, avg_rec_loss: 0.1663794, avg_kl_loss: 0.6603423
# 833. avg_loss: 0.1664977, avg_rec_loss: 0.1664977, avg_kl_loss: 0.6603338
# 834. avg_loss: 0.1666038, avg_rec_loss: 0.1666038, avg_kl_loss: 0.6607542
# 835. avg_loss: 0.1663997, avg_rec_loss: 0.1663997, avg_kl_loss: 0.6607107
# 836. avg_loss: 0.1665215, avg_rec_loss: 0.1665215, avg_kl_loss: 0.6608073
# 837. avg_loss: 0.1657002, avg_rec_loss: 0.1657002, avg_kl_loss: 0.6610088
# 838. avg_loss: 0.1659765, avg_rec_loss: 0.1659765, avg_kl_loss: 0.6609919
# 839. avg_loss: 0.1659275, avg_rec_loss: 0.1659275, avg_kl_loss: 0.6608447
# 840. avg_loss: 0.1653941, avg_rec_loss: 0.1653941, avg_kl_loss: 0.6612759
# 841. avg_loss: 0.1653079, avg_rec_loss: 0.1653079, avg_kl_loss: 0.6611382
# 842. avg_loss: 0.1656417, avg_rec_loss: 0.1656417, avg_kl_loss: 0.6608452
# 843. avg_loss: 0.1658222, avg_rec_loss: 0.1658222, avg_kl_loss: 0.6611123
# 844. avg_loss: 0.1655351, avg_rec_loss: 0.1655351, avg_kl_loss: 0.6613014
# 845. avg_loss: 0.1655971, avg_rec_loss: 0.1655971, avg_kl_loss: 0.6611901
# 846. avg_loss: 0.1660691, avg_rec_loss: 0.1660691, avg_kl_loss: 0.6610726
# 847. avg_loss: 0.1663084, avg_rec_loss: 0.1663084, avg_kl_loss: 0.6611824
# 848. avg_loss: 0.1662551, avg_rec_loss: 0.1662551, avg_kl_loss: 0.6610638
# 849. avg_loss: 0.1658073, avg_rec_loss: 0.1658073, avg_kl_loss: 0.6615196
# 850. avg_loss: 0.1656831, avg_rec_loss: 0.1656831, avg_kl_loss: 0.6615924
# 851. avg_loss: 0.1651693, avg_rec_loss: 0.1651693, avg_kl_loss: 0.6613693
# 852. avg_loss: 0.1654177, avg_rec_loss: 0.1654177, avg_kl_loss: 0.6613918
# 853. avg_loss: 0.1654762, avg_rec_loss: 0.1654762, avg_kl_loss: 0.6616694
# 854. avg_loss: 0.1655396, avg_rec_loss: 0.1655396, avg_kl_loss: 0.6616347
# 855. avg_loss: 0.1650648, avg_rec_loss: 0.1650648, avg_kl_loss: 0.6618316
# 856. avg_loss: 0.1650433, avg_rec_loss: 0.1650433, avg_kl_loss: 0.6617983
# 857. avg_loss: 0.1650939, avg_rec_loss: 0.1650939, avg_kl_loss: 0.6619310
# 858. avg_loss: 0.1651011, avg_rec_loss: 0.1651011, avg_kl_loss: 0.6618544
# 859. avg_loss: 0.1648575, avg_rec_loss: 0.1648575, avg_kl_loss: 0.6618620
# 860. avg_loss: 0.1652568, avg_rec_loss: 0.1652568, avg_kl_loss: 0.6618490
# 861. avg_loss: 0.1653388, avg_rec_loss: 0.1653388, avg_kl_loss: 0.6619026
# 862. avg_loss: 0.1655739, avg_rec_loss: 0.1655739, avg_kl_loss: 0.6619162
# 863. avg_loss: 0.1649420, avg_rec_loss: 0.1649420, avg_kl_loss: 0.6620351
# 864. avg_loss: 0.1651366, avg_rec_loss: 0.1651366, avg_kl_loss: 0.6618341
# 865. avg_loss: 0.1648766, avg_rec_loss: 0.1648766, avg_kl_loss: 0.6621132
# 866. avg_loss: 0.1651279, avg_rec_loss: 0.1651279, avg_kl_loss: 0.6621196
# 867. avg_loss: 0.1653079, avg_rec_loss: 0.1653079, avg_kl_loss: 0.6621323
# 868. avg_loss: 0.1647623, avg_rec_loss: 0.1647623, avg_kl_loss: 0.6620431
# 869. avg_loss: 0.1645024, avg_rec_loss: 0.1645024, avg_kl_loss: 0.6624298
# 870. avg_loss: 0.1652681, avg_rec_loss: 0.1652681, avg_kl_loss: 0.6622946
# 871. avg_loss: 0.1646575, avg_rec_loss: 0.1646575, avg_kl_loss: 0.6625471
# 872. avg_loss: 0.1639719, avg_rec_loss: 0.1639719, avg_kl_loss: 0.6625864
# 873. avg_loss: 0.1645387, avg_rec_loss: 0.1645387, avg_kl_loss: 0.6625899
# 874. avg_loss: 0.1649085, avg_rec_loss: 0.1649085, avg_kl_loss: 0.6624533
# 875. avg_loss: 0.1651798, avg_rec_loss: 0.1651798, avg_kl_loss: 0.6626432
# 876. avg_loss: 0.1645278, avg_rec_loss: 0.1645278, avg_kl_loss: 0.6625659
# 877. avg_loss: 0.1647754, avg_rec_loss: 0.1647754, avg_kl_loss: 0.6629414
# 878. avg_loss: 0.1651859, avg_rec_loss: 0.1651859, avg_kl_loss: 0.6628371
# 879. avg_loss: 0.1643587, avg_rec_loss: 0.1643587, avg_kl_loss: 0.6627175
# 880. avg_loss: 0.1655840, avg_rec_loss: 0.1655840, avg_kl_loss: 0.6626082
# 881. avg_loss: 0.1644324, avg_rec_loss: 0.1644324, avg_kl_loss: 0.6629672
# 882. avg_loss: 0.1647489, avg_rec_loss: 0.1647489, avg_kl_loss: 0.6629386
# 883. avg_loss: 0.1640912, avg_rec_loss: 0.1640912, avg_kl_loss: 0.6630298
# 884. avg_loss: 0.1645051, avg_rec_loss: 0.1645051, avg_kl_loss: 0.6630784
# 885. avg_loss: 0.1642899, avg_rec_loss: 0.1642899, avg_kl_loss: 0.6629307
# 886. avg_loss: 0.1637182, avg_rec_loss: 0.1637182, avg_kl_loss: 0.6630973
# 887. avg_loss: 0.1639567, avg_rec_loss: 0.1639567, avg_kl_loss: 0.6631940
# 888. avg_loss: 0.1642723, avg_rec_loss: 0.1642723, avg_kl_loss: 0.6630166
# 889. avg_loss: 0.1644035, avg_rec_loss: 0.1644035, avg_kl_loss: 0.6631766
# 890. avg_loss: 0.1641966, avg_rec_loss: 0.1641966, avg_kl_loss: 0.6634445
# 891. avg_loss: 0.1645163, avg_rec_loss: 0.1645163, avg_kl_loss: 0.6631933
# 892. avg_loss: 0.1640756, avg_rec_loss: 0.1640756, avg_kl_loss: 0.6631016
# 893. avg_loss: 0.1644114, avg_rec_loss: 0.1644114, avg_kl_loss: 0.6633602
# 894. avg_loss: 0.1642119, avg_rec_loss: 0.1642119, avg_kl_loss: 0.6633422
# 895. avg_loss: 0.1645003, avg_rec_loss: 0.1645003, avg_kl_loss: 0.6635122
# 896. avg_loss: 0.1643221, avg_rec_loss: 0.1643221, avg_kl_loss: 0.6634056
# 897. avg_loss: 0.1634910, avg_rec_loss: 0.1634910, avg_kl_loss: 0.6636990
# 898. avg_loss: 0.1640181, avg_rec_loss: 0.1640181, avg_kl_loss: 0.6633060
# 899. avg_loss: 0.1636791, avg_rec_loss: 0.1636791, avg_kl_loss: 0.6636297
# 900. avg_loss: 0.1642273, avg_rec_loss: 0.1642273, avg_kl_loss: 0.6635978
# 901. avg_loss: 0.1641787, avg_rec_loss: 0.1641787, avg_kl_loss: 0.6635966
# 902. avg_loss: 0.1632184, avg_rec_loss: 0.1632184, avg_kl_loss: 0.6637649
# 903. avg_loss: 0.1632990, avg_rec_loss: 0.1632990, avg_kl_loss: 0.6638996
# 904. avg_loss: 0.1641778, avg_rec_loss: 0.1641778, avg_kl_loss: 0.6637153
# 905. avg_loss: 0.1636140, avg_rec_loss: 0.1636140, avg_kl_loss: 0.6638332
# 906. avg_loss: 0.1635401, avg_rec_loss: 0.1635401, avg_kl_loss: 0.6637025
# 907. avg_loss: 0.1635903, avg_rec_loss: 0.1635903, avg_kl_loss: 0.6637089
# 908. avg_loss: 0.1633806, avg_rec_loss: 0.1633806, avg_kl_loss: 0.6638209
# 909. avg_loss: 0.1640170, avg_rec_loss: 0.1640170, avg_kl_loss: 0.6638714
# 910. avg_loss: 0.1640299, avg_rec_loss: 0.1640299, avg_kl_loss: 0.6639297
# 911. avg_loss: 0.1638241, avg_rec_loss: 0.1638241, avg_kl_loss: 0.6638166
# 912. avg_loss: 0.1636847, avg_rec_loss: 0.1636847, avg_kl_loss: 0.6639438
# 913. avg_loss: 0.1639111, avg_rec_loss: 0.1639111, avg_kl_loss: 0.6639824
# 914. avg_loss: 0.1632425, avg_rec_loss: 0.1632425, avg_kl_loss: 0.6639188
# 915. avg_loss: 0.1635378, avg_rec_loss: 0.1635378, avg_kl_loss: 0.6639135
# 916. avg_loss: 0.1633347, avg_rec_loss: 0.1633347, avg_kl_loss: 0.6640313
# 917. avg_loss: 0.1635787, avg_rec_loss: 0.1635787, avg_kl_loss: 0.6640494
# 918. avg_loss: 0.1634718, avg_rec_loss: 0.1634718, avg_kl_loss: 0.6643090
# 919. avg_loss: 0.1635229, avg_rec_loss: 0.1635229, avg_kl_loss: 0.6642072
# 920. avg_loss: 0.1633979, avg_rec_loss: 0.1633979, avg_kl_loss: 0.6643366
# 921. avg_loss: 0.1630428, avg_rec_loss: 0.1630428, avg_kl_loss: 0.6644822
# 922. avg_loss: 0.1631550, avg_rec_loss: 0.1631550, avg_kl_loss: 0.6643035
# 923. avg_loss: 0.1629204, avg_rec_loss: 0.1629204, avg_kl_loss: 0.6645626
# 924. avg_loss: 0.1628908, avg_rec_loss: 0.1628908, avg_kl_loss: 0.6646909
# 925. avg_loss: 0.1631250, avg_rec_loss: 0.1631250, avg_kl_loss: 0.6644236
# 926. avg_loss: 0.1634687, avg_rec_loss: 0.1634687, avg_kl_loss: 0.6644473
# 927. avg_loss: 0.1631928, avg_rec_loss: 0.1631928, avg_kl_loss: 0.6643384
# 928. avg_loss: 0.1634442, avg_rec_loss: 0.1634442, avg_kl_loss: 0.6643212
# 929. avg_loss: 0.1633925, avg_rec_loss: 0.1633925, avg_kl_loss: 0.6643446
# 930. avg_loss: 0.1627968, avg_rec_loss: 0.1627968, avg_kl_loss: 0.6646762
# 931. avg_loss: 0.1628377, avg_rec_loss: 0.1628377, avg_kl_loss: 0.6646670
# 932. avg_loss: 0.1633362, avg_rec_loss: 0.1633362, avg_kl_loss: 0.6646688
# 933. avg_loss: 0.1631018, avg_rec_loss: 0.1631018, avg_kl_loss: 0.6645771
# 934. avg_loss: 0.1636210, avg_rec_loss: 0.1636210, avg_kl_loss: 0.6645815
# 935. avg_loss: 0.1634075, avg_rec_loss: 0.1634075, avg_kl_loss: 0.6647978
# 936. avg_loss: 0.1626557, avg_rec_loss: 0.1626557, avg_kl_loss: 0.6648250
# 937. avg_loss: 0.1624918, avg_rec_loss: 0.1624918, avg_kl_loss: 0.6649143
# 938. avg_loss: 0.1626839, avg_rec_loss: 0.1626839, avg_kl_loss: 0.6649330
# 939. avg_loss: 0.1631047, avg_rec_loss: 0.1631047, avg_kl_loss: 0.6648902
# 940. avg_loss: 0.1628885, avg_rec_loss: 0.1628885, avg_kl_loss: 0.6651122
# 941. avg_loss: 0.1628916, avg_rec_loss: 0.1628916, avg_kl_loss: 0.6651049
# 942. avg_loss: 0.1632087, avg_rec_loss: 0.1632087, avg_kl_loss: 0.6649198
# 943. avg_loss: 0.1632846, avg_rec_loss: 0.1632846, avg_kl_loss: 0.6650028
# 944. avg_loss: 0.1632433, avg_rec_loss: 0.1632433, avg_kl_loss: 0.6650430
# 945. avg_loss: 0.1628212, avg_rec_loss: 0.1628212, avg_kl_loss: 0.6651504
# 946. avg_loss: 0.1631290, avg_rec_loss: 0.1631290, avg_kl_loss: 0.6653733
# 947. avg_loss: 0.1628830, avg_rec_loss: 0.1628830, avg_kl_loss: 0.6654202
# 948. avg_loss: 0.1628321, avg_rec_loss: 0.1628321, avg_kl_loss: 0.6651804
# 949. avg_loss: 0.1627943, avg_rec_loss: 0.1627943, avg_kl_loss: 0.6650873
# 950. avg_loss: 0.1623903, avg_rec_loss: 0.1623903, avg_kl_loss: 0.6656055
# 951. avg_loss: 0.1625676, avg_rec_loss: 0.1625676, avg_kl_loss: 0.6652690
# 952. avg_loss: 0.1628110, avg_rec_loss: 0.1628110, avg_kl_loss: 0.6653626
# 953. avg_loss: 0.1625033, avg_rec_loss: 0.1625033, avg_kl_loss: 0.6653432
# 954. avg_loss: 0.1629414, avg_rec_loss: 0.1629414, avg_kl_loss: 0.6654811
# 955. avg_loss: 0.1622072, avg_rec_loss: 0.1622072, avg_kl_loss: 0.6654160
# 956. avg_loss: 0.1627550, avg_rec_loss: 0.1627550, avg_kl_loss: 0.6655041
# 957. avg_loss: 0.1619379, avg_rec_loss: 0.1619379, avg_kl_loss: 0.6656794
# 958. avg_loss: 0.1624081, avg_rec_loss: 0.1624081, avg_kl_loss: 0.6657528
# 959. avg_loss: 0.1628620, avg_rec_loss: 0.1628620, avg_kl_loss: 0.6656144
# 960. avg_loss: 0.1622349, avg_rec_loss: 0.1622349, avg_kl_loss: 0.6657982
# 961. avg_loss: 0.1626962, avg_rec_loss: 0.1626962, avg_kl_loss: 0.6656593
# 962. avg_loss: 0.1625812, avg_rec_loss: 0.1625812, avg_kl_loss: 0.6657946
# 963. avg_loss: 0.1630599, avg_rec_loss: 0.1630599, avg_kl_loss: 0.6656601
# 964. avg_loss: 0.1627631, avg_rec_loss: 0.1627631, avg_kl_loss: 0.6658996
# 965. avg_loss: 0.1622895, avg_rec_loss: 0.1622895, avg_kl_loss: 0.6659367
# 966. avg_loss: 0.1626723, avg_rec_loss: 0.1626723, avg_kl_loss: 0.6657115
# 967. avg_loss: 0.1623525, avg_rec_loss: 0.1623525, avg_kl_loss: 0.6660581
# 968. avg_loss: 0.1620620, avg_rec_loss: 0.1620620, avg_kl_loss: 0.6658541
# 969. avg_loss: 0.1622911, avg_rec_loss: 0.1622911, avg_kl_loss: 0.6661961
# 970. avg_loss: 0.1619266, avg_rec_loss: 0.1619266, avg_kl_loss: 0.6661611
# 971. avg_loss: 0.1622190, avg_rec_loss: 0.1622190, avg_kl_loss: 0.6660756
# 972. avg_loss: 0.1616631, avg_rec_loss: 0.1616631, avg_kl_loss: 0.6663598
# 973. avg_loss: 0.1619166, avg_rec_loss: 0.1619166, avg_kl_loss: 0.6662390
# 974. avg_loss: 0.1618773, avg_rec_loss: 0.1618773, avg_kl_loss: 0.6663015
# 975. avg_loss: 0.1620371, avg_rec_loss: 0.1620371, avg_kl_loss: 0.6662441
# 976. avg_loss: 0.1622427, avg_rec_loss: 0.1622427, avg_kl_loss: 0.6662253
# 977. avg_loss: 0.1620015, avg_rec_loss: 0.1620015, avg_kl_loss: 0.6664413
# 978. avg_loss: 0.1620932, avg_rec_loss: 0.1620932, avg_kl_loss: 0.6663299
# 979. avg_loss: 0.1622502, avg_rec_loss: 0.1622502, avg_kl_loss: 0.6663866
# 980. avg_loss: 0.1615404, avg_rec_loss: 0.1615404, avg_kl_loss: 0.6664621
# 981. avg_loss: 0.1624409, avg_rec_loss: 0.1624409, avg_kl_loss: 0.6664604
# 982. avg_loss: 0.1625693, avg_rec_loss: 0.1625693, avg_kl_loss: 0.6661248
# 983. avg_loss: 0.1613165, avg_rec_loss: 0.1613165, avg_kl_loss: 0.6667255
# 984. avg_loss: 0.1624901, avg_rec_loss: 0.1624901, avg_kl_loss: 0.6666047
# 985. avg_loss: 0.1614278, avg_rec_loss: 0.1614278, avg_kl_loss: 0.6666532
# 986. avg_loss: 0.1615847, avg_rec_loss: 0.1615847, avg_kl_loss: 0.6666650
# 987. avg_loss: 0.1623297, avg_rec_loss: 0.1623297, avg_kl_loss: 0.6663941
# 988. avg_loss: 0.1624769, avg_rec_loss: 0.1624769, avg_kl_loss: 0.6666478
# 989. avg_loss: 0.1617451, avg_rec_loss: 0.1617451, avg_kl_loss: 0.6668430
# 990. avg_loss: 0.1617132, avg_rec_loss: 0.1617132, avg_kl_loss: 0.6667815
# 991. avg_loss: 0.1620619, avg_rec_loss: 0.1620619, avg_kl_loss: 0.6669646
# 992. avg_loss: 0.1610493, avg_rec_loss: 0.1610493, avg_kl_loss: 0.6670703
# 993. avg_loss: 0.1619303, avg_rec_loss: 0.1619303, avg_kl_loss: 0.6669134
# 994. avg_loss: 0.1616232, avg_rec_loss: 0.1616232, avg_kl_loss: 0.6670214
# 995. avg_loss: 0.1613452, avg_rec_loss: 0.1613452, avg_kl_loss: 0.6668798
# 996. avg_loss: 0.1619236, avg_rec_loss: 0.1619236, avg_kl_loss: 0.6669081
# 997. avg_loss: 0.1622181, avg_rec_loss: 0.1622181, avg_kl_loss: 0.6667759
# 998. avg_loss: 0.1621944, avg_rec_loss: 0.1621944, avg_kl_loss: 0.6669287
# 999. avg_loss: 0.1618851, avg_rec_loss: 0.1618851, avg_kl_loss: 0.6669489
# 1000. avg_loss: 0.1612677, avg_rec_loss: 0.1612677, avg_kl_loss: 0.6673093

# %%
# 儲存loss數據（還沒加上alpha, beta, gamma）
df = pd.DataFrame({
    "avg_rec_loss": avg_rec_loss,
    "avg_kl_loss": avg_kl_loss,
    "avg_loss": avg_loss
})
df.to_csv("epoch_loss.csv", index=False)

# %% [markdown]
# ## 畫loss-epoch curve

# %%
# 定義x軸
x_size = len(avg_loss)
print(f"x_size: {x_size}")
x = np.linspace(0, x_size, x_size)

# 建立圖形和第一個y軸
fig, ax1 = plt.subplots(figsize=(7,5))
# 繪製第一組數據: avg_loss
ax1.plot(x, avg_loss, 'r-', label="loss")
ax1.set_xlabel('batch')
ax1.set_ylabel('loss', color='r')
# ax1.set_yscale('log')
ax1.set_ylim(bottom=0)
ax1.tick_params(axis='y', labelcolor='r')
# 強制 y1 使用科學記號
ax1.yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))  # 強制啟用科學記號
# ax1.get_yaxis().get_offset_text().set_position((, 0))  # 手動移動科學記號標示位置

# 建立第二個y軸: avg_rec_loss
ax2 = ax1.twinx()
ax2.plot(x, avg_rec_loss, 'b--', label="rec_loss")
ax2.set_ylabel('avg_rec_loss', color='b')
ax2.set_ylim(bottom=0)
ax2.tick_params(axis='y', labelcolor='b')
# 強制 y2 使用科學記號
ax2.yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))  # 強制啟用科學記號
ax2.get_yaxis().get_offset_text().set_position((1.05, 0))  # 手動移動科學記號標示位置

# 建立第三個y軸: batch_kl_loss
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 70))  # 將第三個y軸移開一點
ax3.plot(x, avg_kl_loss, 'g-.', label="kl_loss")
ax3.set_ylabel('avg_kl_loss', color='g')
ax3.tick_params(axis='y', labelcolor='g')
# 強制 y3 使用科學記號
ax3.yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))  # 強制啟用科學記號
ax3.get_yaxis().get_offset_text().set_position((1.28, 0))  # 手動移動科學記號標示位置

plt.xlim(left=0, right=x_size)
plt.ylim(bottom=0)

# 顯示圖例
fig.tight_layout()  # 確保佈局不重疊
plt.savefig("test.png")
plt.show()
# Out:
# x_size: 1000

# %% [markdown]
# # 推論
# 測試
# - 訓練集跟測試集每個epoch的平均準確率（可能甚至要到batch）
#   - 理想情況：訓練集跟測試集的準確率都隨著epoch增加而增加（增加的幅度會越來越慢），訓練集的準確率略高於測試集
#   - 過擬合：訓練集的準確率繼續增加，但測試集的準確率下降
# - 生成環數要合理、應該所有環數都要生成的到並且是平均的

# %%
batch_size = 2000

# %%
# DataLoader
dataloader_train = DataLoader(dataset=dataset_train,
                             batch_size=batch_size,
                             shuffle=False)
dataloader_test  = DataLoader(dataset=dataset_test,
                              batch_size=batch_size,
                              shuffle=False)

# %%
# Show Image
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

def show_logits(logits):
    '''
    input
    - logits.shape: [batch_size, N*K]
    '''
    sqrtn = int(np.ceil(np.sqrt(logits.shape[0])))
    for index, logit in enumerate(logits):
        plt.subplot(sqrtn, sqrtn, index+1)
        plt.imshow(logit.reshape(N, K))
        plt.axis('off')
    plt.show()

# %%
# model.eval()

# with torch.no_grad():
    
#     for data in dataloader_test:
    
#         inputs = data
#         print("inputs.shape:", inputs.shape)
    
#         # Inputs
#         # for i, vector in enumerate(inputs):
#         #     print(f"Batch {i+1}:")
#         #     for j in range(0, len(vector), 10):
#         #         print(vector[j:j+10].int().tolist())
#         #     print("-" * 30)  # 分隔每個 batch
    
#         # Inference/Forward
#         logits, latent_code, outputs = model(inputs, temperature=0.01)
#         '''
#         - logits.shape: [batch_size, N*K]
#         - latent_codes.shape: [batch_size, N*K]
#         - outputs.shape: [batch_size, flatten_img_size]
#         '''
        
#         # Logits
#         # print("logits.shape:", logits.shape)
#         # show_logits(logits)

#         # Latent Code
#         # print("latent_code.shape:", latent_code.shape)
#         # show_logits(latent_code)
        
#         # Outputs
#         outputs = (outputs>=0.5).int().float()
#         # for i, vector in enumerate(outputs):
#         #     print(f"Batch {i+1}:")
#         #     for j in range(0, len(vector), 10):
#         #         print(vector[j:j+10].int().tolist())
#         #     print("-" * 30)  # 分隔每個 batch

#         # 正確率
#         equal_elements = inputs == outputs                          # 比對每個元素是否相等，結果是布林值的 tensor
#         batch_equal_counts = equal_elements.sum(dim=1)              # 對每個 batch 計算相等的元素數量
        
#         # print("每個 batch 中相等的比例")
#         ratio = batch_equal_counts/512*100
#         ratio = ratio.to("cpu").numpy()
#         # for i in range(len(ratio)):
#         #     print(f"{ratio[i]:.0f}", end=', ')
#         #     if i % 10 == 9:
#         #         print("")
#         avg_accuracy = np.mean(ratio)    # 對batch取平均
#         std_accuracy = np.std(ratio)
#         print(f"正確率的平均值：{avg_accuracy:.2f}%")
#         print(f"正確率的標準差：{std_accuracy:.2f}%")

# %% [markdown]
# ## 測試不同epoch的model在training set跟testing set上的正確率

# %%
avg_accuracy_train = []
avg_accuracy_test  = []

for i in range(1, x_size):
    checkpoint = torch.load(f"./lucky/checkpoint_epoch_{i}.pth", weights_only=True)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    
    with torch.no_grad():
        
        # training set的數據
        data = next(iter(dataloader_train))
        inputs = data
        logits, latent_code, outputs = model(inputs, temperature=0.01)
        outputs = (outputs>=0.5).int().float()
        # 正確率
        equal_elements = inputs == outputs
        batch_equal_counts = equal_elements.sum(dim=1)
        ratio = batch_equal_counts/512*100
        ratio = ratio.to("cpu").numpy()
        
        avg_accuracy_train.append( np.mean(ratio) )
        
        # testing set的數據
        data = next(iter(dataloader_test))
        inputs = data
        logits, latent_code, outputs = model(inputs, temperature=0.01)
        outputs = (outputs>=0.5).int().float()
        # 正確率
        equal_elements = inputs == outputs
        batch_equal_counts = equal_elements.sum(dim=1)
        ratio = batch_equal_counts/512*100
        ratio = ratio.to("cpu").numpy()
        
        avg_accuracy_test.append( np.mean(ratio) )

# %%
# 畫accuracy-epoch圖
fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot()
ax.plot(avg_accuracy_train, label="training set")
ax.plot(avg_accuracy_test, label="testing set")
ax.set_xlabel("epoch")
ax.set_ylabel("accuracy")
ax.legend()
fig.savefig("accuracy-epoch.png")

# %%
print(np.max(avg_accuracy_train))
print(np.max(avg_accuracy_test))
# Out:
# 92.00215
# 87.554596

# %%
# %matplotlib inline
plt.ioff()    # 關閉及時顯示模式
# 畫出等效圖
acc = []
for i in range(20):
    equal_elements = inputs[i] == outputs[i]
    equal_elements = equal_elements.sum()
    equal_elements = equal_elements.to("cpu").numpy()
    # print(equal_elements)
    # print(f"ratio: {equal_elements/512*100}%")
    acc.append( equal_elements / 512 * 100 )
    rings_utils.plot_rings(inputs[i], path=f"./rings_img/rings_inputs_{i}.png")
    rings_utils.plot_rings(outputs[i], path=f"./rings_img/rings_output_{i}.png")

# %%
# 畫出每個測試的準確率
plt.close('all')
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot()
ax.plot(acc)
from matplotlib.ticker import MultipleLocator
plt.gca().xaxis.set_major_locator(MultipleLocator(1))
plt.show()

# %% [markdown]
# # Generation

# %%
# 第一個criteria：latent vector變動一點點，output應該也要只能變動一點點

def hamming_dist(str1, str2):
    if len(str1) != len(str2):
        raise ValueError("兩個字串的長度必須相同")
    return sum(c1 != c2 for c1, c2 in zip(str1, str2))

def eval_1(latent_code):
    '''
    latent_code變動一點，看輸出變動多少
    K=2，且要已經binarized
    latent_code.shape: [batch_size, vec_size]    
    '''
    batch_size = len(latent_code)
    vec_size   = len(latent_code[0])

    # 變動一個latent_code的元素（要把它拆成兩半，另一半也要變）
    latent_code_new = latent_code.clone()
    for i in range(batch_size):
        idx_front = random.randint(1, vec_size//2) - 1
        idx_rear  = idx_front + vec_size//2
        latent_code_new[i][idx_front] = 0.0 if latent_code_new[i][idx_front] == 1.0 else 1.0
        latent_code_new[i][idx_rear]  = 0.0 if latent_code_new[i][idx_rear] == 1.0 else 1.0

    # 計算輸出的差異
    outputs     = model.decode(latent_code)
    outputs     = (outputs>=0.5).int().float()
    outputs_new = model.decode(latent_code_new)
    outputs_new = (outputs_new>=0.5).int().float()
    
    diff = []
    for i in range(batch_size):
        diff.append(hamming_dist(outputs[i], outputs_new[i]) / 512 * 100)    # 不同輸出的比例%
    diff = np.array( [tensor.item() for tensor in diff] )    # diff.shape: [batch_size]

    # 畫環
    k=1
    rings_utils.plot_rings(outputs[k], save=False)
    rings_utils.plot_rings(outputs_new[k], save=False)
    
    avg_diff = np.mean(diff)
    std_diff = np.std(diff)
    return avg_diff, std_diff
    
    # # 畫直方圖統計
    # bins = range(0, 100, 1)  # 從0到30，每5為一個區間
    
    # # 繪製直方圖
    # plt.hist(diff, bins=bins, edgecolor='black')
    # plt.title('Histogram of diff')
    # plt.xlabel('Value Range')
    # plt.ylabel('Frequency')
    # plt.xticks(bins)  # 設置x軸的刻度
    # plt.grid(axis='y', linestyle='--', alpha=0.7)
    # plt.show()

# %%
# 第二個criteria：假設rec_loss夠好，隨機抽樣一筆latent vector再經過decoder, encoder回來得到的latent vector比對後就可以評斷decoder的好壞

def eval_2(latent_code):
    pass
    # inputs = outputs
    # latent_code_new = model.encode(inputs)

    # latent_code_new = (latent_code_new>=0.5).int().float()
    # # 正確率
    # equal_elements = latent_code == latent_code_new             # 比對每個元素是否相等，結果是布林值的 tensor
    # batch_equal_counts = equal_elements.sum(dim=1)              # 對每個 batch 計算相等的元素數量
    # print("每個 batch 中相等的元素數量：", batch_equal_counts)
    # print("每個 batch 中相等的元素比例：", batch_equal_counts/len(latent_code[0]))

# %%
# 第三個criteria：判斷書出的環數有沒有小於threshold（但是有可能小小的出錯就讓他多了很多等校環）
def eval_3(latent_code):
    '''
    input
    - latent_code.shape: [batch_size, vec_size]
    '''
    outputs = model.decode(latent_code)
    outputs = (outputs>=0.5).int().float()
    
    nums = []    # 紀錄每個batch的等效環數
    for i in range(len(latent_code)):
        nums.append( rings_utils.equiv_rings(outputs[i]) )
        # print(f"等效環數：{nums[i]}")
    nums = np.array(nums)
    
    avg_nums = np.mean(nums)    # 等效環數的平均值
    std_nums = np.std(nums)     # 等效環數的標準差
    return avg_nums, std_nums

# %%
batch_size = 1000
temperature = 0.01
with torch.no_grad():
    logits = torch.rand((batch_size, N, K), device=device)
    latent_code = model.gumbel_softmax(logits, temperature)
    latent_code = (latent_code>=0.5).int().float()

    # 評估生成模型的好壞
    avg_diff, std_diff = eval_1(latent_code)
    print(f"變化比例的平均值：{avg_diff:.2f}%")    # 正常情況應該10%左右
    print(f"變化比例的標準差：{std_diff:.2f}%")    # 應該要盡量小ㄅ

    print("------------------------------------------")
    
    avg_nums, std_nums = eval_3(latent_code)
    print(f"等效環數的平均值：{avg_nums:.2f}")    # 正常情況應該要小於50，極限就是超過50一點
    print(f"等效環數的標準差：{std_nums:.2f}")    # 應該要盡量小ㄅ
# Out:
# 變化比例的平均值：5.76%
# 變化比例的標準差：1.47%
# ------------------------------------------
# 等效環數的平均值：42.98
# 等效環數的標準差：5.93
